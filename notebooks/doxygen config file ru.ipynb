# %% [markdown]
# <pre>
# # Doxyfile 1.8.7
#
# # Этот файл описывает настройки, которые будут использоваться системой документации
# # doxygen (www.doxygen.org) для проекта.
# #
# # Весь текст после двойного хеша (##) считается комментарием и помещается в
# # перед TAG, которому он предшествует.
# #
# # Весь текст после одного хеша (#) считается комментарием и будет проигнорирован.
# # Формат:
# # TAG = value [значение, ...]
# # Для списков элементы также могут быть добавлены с помощью:
# # TAG += value [значение, ...]
# # Значения, содержащие пробелы, должны быть помещены между кавычками (\" \").
#
# #---------------------------------------------------------------------------
# # Параметры конфигурации, связанные с проектом
# #---------------------------------------------------------------------------
#
# # Этот тег указывает кодировку, используемую для всех символов в конфигурационном файле
# # которые следуют. По умолчанию используется UTF-8, которая также является кодировкой, используемой для всего текста
# # до первого вхождения этого тега. Doxygen использует libiconv (или iconv
# # встроен в libc) для перекодирования. Смотрите http://www.gnu.org/software/libiconv
# # для списка возможных кодировок.
# # Значение по умолчанию: UTF-8.
#
# DOXYFILE_ENCODING      = UTF-8
#
# # Тег PROJECT_NAME представляет собой одно слово (или последовательность слов, окруженных
# # двойные кавычки, если вы не используете Doxywizard), который должен идентифицировать
# # проект, для которого генерируется документация. Это имя используется в
# # заголовок большинства сгенерированных страниц и в некоторых других местах.
# # Значение по умолчанию: Мой проект.
#
# PROJECT_NAME           = "hypotez"
#
# # Тег PROJECT_NUMBER может быть использован для ввода номера проекта или редакции. Этот
# # может быть удобно для архивирования сгенерированной документации или если какая-то версия
# # используется система управления.
#
# PROJECT_NUMBER         = 0.1.0
#
# # С помощью тега PROJECT_BRIEF можно указать необязательное описание в одну строку
# # для проекта, который отображается в верхней части каждой страницы и должен давать зрителю
# # Быстрое представление о цели проекта. Описание должно быть кратким.
#
# PROJECT_BRIEF          = "spyder & parser"
#
# # С помощью тега PROJECT_LOGO можно указать логотип или иконку, которая включена в
# # Документация. Максимальная высота логотипа не должна превышать 55 пикселей
# # и максимальная ширина не должна превышать 200 пикселей. Doxygen скопирует логотип
# # в выходной каталог.
#
# PROJECT_LOGO           =
#
# # Тег OUTPUT_DIRECTORY используется для указания (относительного или абсолютного) пути
# #, в который будет записана сгенерированная документация. Если относительный путь равен
# #, он будет относительно места, где был запущен doxygen. Если
# # Оставлено пустым, будет использоваться текущий каталог.
#
# OUTPUT_DIRECTORY = _build
#
# # Если тег CREATE_SUBDIRS установлен в YES, то doxygen создаст 4096 sub-
# # каталоги (в 2-х уровнях) под выходным каталогом каждого выходного формата и
# # распределит сгенерированные файлы по этим каталогам. Включение этого параметра
# # может быть полезна при подаче doxygen огромного количества исходных файлов, где
# # Помещение всех сгенерированных файлов в один каталог в противном случае приведет к
# # проблемы с производительностью файловой системы.
# # Значение по умолчанию: NO.
#
# CREATE_SUBDIRS = YES
#
# # Если тег ALLOW_UNICODE_NAMES установлен в YES, doxygen будет разрешать не-ASCII
# # символы, которые будут отображаться в именах сгенерированных файлов. Если установлено значение NO, не ASCII
# # символы будут экранированы, например, _xE3_x81_x84 будет использоваться для Unicode
# # U+3044.
# # Значение по умолчанию: NO.
#
# ALLOW_UNICODE_NAMES = YES
#
# # Тег OUTPUT_LANGUAGE используется для указания языка, на котором все
# # Написана документация, сгенерированная doxygen. Doxygen будет использовать это
# # information для генерации всех константных выходных данных на нужном языке.
# # Возможные значения: африкаанс, арабский, армянский, бразильский, каталанский, китайский,
# # Китайский-традиционный, Хорватский, Чешский, Датский, Голландский, Английский (США),
# # Эсперанто, Фарси (Персидский), Финский, Французский, Немецкий, Греческий, Венгерский,
# # Индонезийский, Итальянский, Японский, Японский-en (Японский с английскими надписями),
# # Корейский, Корейский-en (корейский с английскими сообщениями), Латышский, Литовский,
# # Македонский, Норвежский, Персидский (фарси), Польский, Португальский, Румынский, Русский,
# # Сербский, Сербский-кириллический, Словацкий, Словенский, Испанский, Шведский, Турецкий,
# # Украинский и вьетнамский.
# # Значение по умолчанию: English.
#
# OUTPUT_LANGUAGE = English
#
# # Если тег BRIEF_MEMBER_DESC установлен в YES, doxygen будет включать краткий член
# # описания после членов, перечисленных в файле и классе
# # documentation (аналог Javadoc). Установите значение NO, чтобы отключить эту функцию.
# # Значение по умолчанию: YES.
#
# BRIEF_MEMBER_DESC = YES
#
# # Если тег REPEAT_BRIEF установлен в YES, doxygen будет предварять бриф
# # описание члена или функции перед подробным описанием
# #
# # Замечание: Если и HIDE_UNDOC_MEMBERS, и BRIEF_MEMBER_DESC установлены в NO, то
# # Краткие описания будут полностью подавлены.
# # Значение по умолчанию: YES.
#
# REPEAT_BRIEF = NO
#
# # Этот тег реализует квази-интеллектуальный сокращатель краткого описания, который используется
# # для формирования текста в различных списках. Каждая строка в этом списке, если найдена
# # в качестве ведущего текста краткого описания, будет удалена из текста
# # и результат, после обработки всего списка, используется как аннотированный
# # текст. В противном случае краткое описание используется в неизменном виде. Если оставлено пустым,
# # используются следующие значения ($name автоматически заменяется именем
# # сущности): Класс $name, Виджет $name, Файл $name, является, предоставляет,
# # указывает, содержит, представляет собой, a, an и the.
#
#
# ABBREVIATE_BRIEF       =
#
# # Если теги ALWAYS_DETAILED_SEC и REPEAT_BRIEF установлены в YES, то
# # doxygen сгенерирует подробный раздел, даже если есть только бриф
# # Описание.
# # Значение по умолчанию: NO.
#
# ALWAYS_DETAILED_SEC = NO
#
# # Если тег INLINE_INHERITED_MEMB установлен в YES, doxygen покажет все
# # наследуются члены класса в документации этого класса, как если бы эти
# # члены были обычными членами класса. Конструкторы, деструкторы и назначение
# # операторы базовых классов не будут показаны.
# # Значение по умолчанию: NO.
#
# INLINE_INHERITED_MEMB = NO
#
# # Если тег FULL_PATH_NAMES установлен в YES, doxygen будет добавлять полный путь
# # перед именем файлов в списке файлов и в заголовочных файлах. Если установлено значение NO, то
# # будет использован кратчайший путь, который делает имя файла уникальным
# # Значение по умолчанию: YES.
#
# FULL_PATH_NAMES = YES
#
# # Тег STRIP_FROM_PATH может быть использован для удаления пользовательской части пути.
# # Зачистка выполняется только в том случае, если одна из указанных строк совпадает с левой
# # часть пути. Тег можно использовать для отображения относительных путей в списке файлов.
# # Если оставить пустым, то в качестве пути к каталогу будет запущен doxygen
# # полоса.
# #
# # Обратите внимание, что здесь вы можете указать не только абсолютные пути, но и относительные пути, которые
# # будет относительным по отношению к директории, в которой запущен doxygen.
# # Этот тег требует, чтобы FULL_PATH_NAMES тега был установлен в YES.
#
# STRIP_FROM_PATH        =
#
# # Тег STRIP_FROM_INC_PATH может быть использован для удаления пользовательской части тега
# # путь, упомянутый в документации класса, который сообщает читателю, что
# # заголовочный файл, который нужно включить для использования класса. Если оставить пустым, укажите только имя
# # используется заголовочный файл, содержащий определение класса. В противном случае следует
# # указываем список включаемых путей, которые обычно передаются компилятору
# # с помощью флага -I.
#
# STRIP_FROM_INC_PATH    =
#
# # Если тег SHORT_NAMES установлен в YES, doxygen будет генерировать гораздо меньше (но
# # менее читаемые) имена файлов. Это может быть полезно, если ваши файловые системы этого не делают
# # поддержка длинных имен, как в DOS, Mac или CD-ROM.
# # Значение по умолчанию: NO.
#
# SHORT_NAMES = NO
#
# # Если тег JAVADOC_AUTOBRIEF установлен в YES, то doxygen будет интерпретировать
# # первая строка (до первой точки) комментария в стиле Javadoc в качестве брифа
# # Описание. Если установлено значение NO, то Javadoc-стиль будет вести себя так же, как обычный Qt-
# # style комментариев (таким образом, требуется явная команда @brief для краткого описания
# # описание.)
# # Значение по умолчанию: NO.
#
# JAVADOC_AUTOBRIEF = NO
#
# # Если тег QT_AUTOBRIEF установлен в YES, то doxygen будет интерпретировать первый
# # (до первой точки) комментария в стиле Qt в качестве краткого описания. Если
# # установлено в NO, Qt-стиль будет вести себя так же, как обычные комментарии в стиле Qt (таким образом,
# # требующая явной команды \brief для краткого описания.)
# # Значение по умолчанию: NO.
#
# QT_AUTOBRIEF = NO
#
# # Тег MULTILINE_CPP_IS_BRIEF может быть установлен в значение YES, чтобы doxygen обрабатывал
# # многострочный специальный блок комментариев C++ (т.е. блок комментариев //! или /// ) в виде
# # краткое описание. Раньше это было поведение по умолчанию. Новое значение по умолчанию —
# # для обработки многострочного блока комментариев C++ как подробного описания. Установите этот параметр
# # в YES, если вы предпочитаете старое поведение.
# #
# # Обратите внимание, что установка этого тега в YES также означает, что рациональные комментарии rose
# # больше не распознается.
# # Значение по умолчанию: NO.
#
# MULTILINE_CPP_IS_BRIEF = NO
#
# # Если тег INHERIT_DOCS установлен в YES, то недокументированный член наследует
# # документацию от любого документированного члена, который он повторно реализует.
# # Значение по умолчанию: YES.
#
# INHERIT_DOCS = YES
#
# # Если тег SEPARATE_MEMBER_PAGES установлен в YES, то doxygen выдаст
# # новая страница для каждого участника. Если установлено значение NO, документация участника будет иметь вид
# # часть файла/класса/пространства имен, которая его содержит.
# # Значение по умолчанию: NO.
#
# SEPARATE_MEMBER_PAGES = NO
#
# # Тег TAB_SIZE можно использовать для установки количества пробелов во вкладке. Кислород
# # использует это значение для замены табуляции пробелами во фрагментах кода.
# # Минимальное значение: 1, максимальное значение: 16, значение по умолчанию: 4.
#
# TAB_SIZE               = 4
#
# # Этот тег может быть использован для указания ряда псевдонимов, которые действуют как команды в
# # Документация. Псевдоним имеет вид:
# # имя=значение
# # Например, добавление
# # "sideeffect=@par Побочные эффекты:\n"
# # позволит вам поместить команду \sideeffect (или @sideeffect) в
# #, в результате чего получится пользовательский абзац с заголовком
# # "Побочные эффекты:". Вы можете поместить \n в часть значения псевдонима для вставки
# # переводы строк.
#
# ALIASES =                "rst=\verbatim embed:rst" \
#                          endrst=\endverbatim \
#                          "english=\if english" \
#                          endenglish=\endif \
#                          "russian=\if russian" \
#                          enrussian=\endif
#
# # Этот тег может быть использован для указания нескольких сопоставлений слов и ключевых слов (только TCL).
# # Отображение имеет вид "имя=значение". Например, добавление "class=itcl::class"
# # позволит использовать командный класс в значении itcl::class.
#
# TCL_SUBST              =
#
# # Установите тег OPTIMIZE_OUTPUT_FOR_C в значение YES, если ваш проект состоит из исходных текстов на C
# # только. Затем Doxygen будет генерировать продукцию, более адаптированную для C. Для
# #, некоторые из используемых имен будут отличаться. Список всех
# # члены будут опущены и т.д.
# # Значение по умолчанию: NO.
#
# OPTIMIZE_OUTPUT_FOR_C = NO
#
# # Установите тег OPTIMIZE_OUTPUT_JAVA в YES, если ваш проект состоит из Java или
# # Только исходные коды Python. В этом случае Doxygen будет генерировать более индивидуальную продукцию
# # для этого языка. Например, пространства имен будут представлены в виде пакетов,
# # квалифицированные области видимости будут выглядеть по-разному и т.д.
# # Значение по умолчанию: NO.
#
# OPTIMIZE_OUTPUT_JAVA = YES
#
# # Установите тег OPTIMIZE_FOR_FORTRAN в YES, если ваш проект состоит из Fortran
# # источники. Затем Doxygen будет генерировать выходные данные, адаптированные для Fortran.
# # Значение по умолчанию: NO.
#
# OPTIMIZE_FOR_FORTRAN = NO
#
# # Установите тег OPTIMIZE_OUTPUT_VHDL в YES, если ваш проект состоит из VHDL
# # источники. Затем Doxygen генерирует выходной сигнал, адаптированный для VHDL.
# # Значение по умолчанию: NO.
#
# OPTIMIZE_OUTPUT_VHDL = NO
#
# # Doxygen выбирает парсер для использования в зависимости от расширения файлов, которые он использует
# # парсинг. С помощью этого тега вы можете указать, какой парсер использовать для данного
# # расширение. Doxygen имеет встроенное отображение, но вы можете переопределить или расширить его
# # с помощью этого тега. Формат — ext=language, где ext — расширение файла, а
# # язык является одним из парсеров, поддерживаемых doxygen: IDL, Java, Javascript,
# # C#, C, C++, D, PHP, Objective-C, Python, Fortran (фиксированный формат Fortran:
# # FortranИсправленный, свободный формат Fortran: FortranFree, неизвестный форматированный Fortran:
# # Фортран. В последнем случае парсер пытается угадать, является ли код фиксированным
# # или код в свободном формате, это код по умолчанию для файлов типа Fortran), VHDL. Для
# # экземпляр для того, чтобы doxygen обрабатывал файлы .inc как файлы Fortran (по умолчанию PHP),
# # и .f файлы как C (по умолчанию Fortran), используйте: inc=Fortran f=C.
# #
# # Примечание: Для файлов без расширения вы можете использовать no_extension в качестве заполнителя.
# #
# # Обратите внимание, что для пользовательских расширений вам также нужно установить FILE_PATTERNS иначе
# # doxygen не читает файлы.
#
# EXTENSION_MAPPING      = Python
#
# # Если тег MARKDOWN_SUPPORT включен, то doxygen предварительно обрабатывает все комментарии
# # в соответствии с форматом Markdown, что позволяет сделать его более читабельным
# # документация. Подробнее см. http://daringfireball.net/projects/markdown/.
# # Результат обработки markdown дополнительно обрабатывается doxygen, поэтому вы можете
# # смешивать команды doxygen, HTML и XML с форматированием Markdown. Отключить только в
# # Случай проблем с обратной совместимостью.
# # Значение по умолчанию: YES.
#
# MARKDOWN_SUPPORT = YES
#
# # Когда эта опция включена, doxygen пытается связать слова, которые соответствуют документированным
# # или пространства имён к соответствующей документации. Такая ссылка может
# # предотвращаться в отдельных случаях путем постановки знака % перед словом
# # или глобально, установив для AUTOLINK_SUPPORT значение NO.
# # Значение по умолчанию: YES.
#
# AUTOLINK_SUPPORT = YES
#
# # Если вы используете STL-классы (т.е. std::string, std::vector и т.д.), но не хотите
# # чтобы включить (файл тегов для) исходных текстов STL в качестве входных данных, то вы должны установить это
# # в YES, чтобы doxygen соответствовал объявлениям функций и
# # определения, аргументы которых содержат STL-классы (например, func(std::string);
# # против func(std::string) {}). Это также делает наследование и сотрудничество
# # диаграммы, в которых задействованы STL-классы, более полные и точные.
# # Значение по умолчанию: NO.
#
# BUILTIN_STL_SUPPORT = YES
#
# # Если вы используете язык Microsoft C++/CLI, вы должны установить эту опцию в значение YES, чтобы
# # включить поддержку парсинга.
# # Значение по умолчанию: NO.
#
# CPP_CLI_SUPPORT = NO
#
# # Установите тег SIP_SUPPORT в YES, если ваш проект состоит из sip (см.:
# # http://www.riverbankcomputing.co.uk/software/sip/intro) только источники. Кислород
# # будет анализировать их, как обычный C++, но будет предполагать, что все классы используют public вместо этого
# # приватного наследования, когда отсутствует явное ключевое слово protection.
# # Значение по умолчанию: NO.
#
# SIP_SUPPORT = NO
#
# # Для IDL от Microsoft есть атрибуты propget и propput для указания
# # методы геттера и сеттера для свойства. Установка этого параметра в YES приведет к тому, что
# # doxygen для замены методов get и set на свойство в документации.
# # Это будет работать только в том случае, если методы действительно получают или устанавливают простой
# # тип. Если это не так, или вы все равно хотите показать методы, вы
# # должен установить эту опцию в NO.
# # Значение по умолчанию: YES.
#
# IDL_PROPERTY_SUPPORT = YES
#
# # Если в документации и DISTRIBUTE_GROUP_DOC используется группировка элементов
# # установлен в YES, то doxygen будет повторно использовать документацию первого
# # участник в группе (если есть) для остальных участников группы. По умолчанию
# # Все члены группы должны быть явно задокументированы.
# # Значение по умолчанию: NO.
#
# DISTRIBUTE_GROUP_DOC = NO
#
# # Установите тег SUBGROUPING в значение YES, чтобы разрешить группы членов класса одного типа
# # (например, группа публичных функций), которая должна быть помещена в подгруппу этого
# # (например, в разделе Public Functions). Установите его в NO, чтобы предотвратить
# # подгруппировка. Кроме того, это можно сделать для каждого класса с помощью метода
# # \nosubgrouping.
# # Значение по умолчанию: YES.
#
# SUBGROUPING = YES
#
# # Если тег INLINE_GROUPED_CLASSES установлен в YES, классы, структуры и объединения
# # показываются внутри группы, в которую они включены (например, с помощью \ingroup)
# # вместо отдельной страницы (для HTML и Man страниц) или раздела (для LaTeX
# # и RTF).
# #
# # Обратите внимание, что эта функция не работает в сочетании с
# # SEPARATE_MEMBER_PAGES.
# # Значение по умолчанию: NO.
#
# INLINE_GROUPED_CLASSES = NO
#
# # Если для тега INLINE_SIMPLE_STRUCTS установлено значение YES, структуры, классы и объединения
# # только с публичными полями данных или простыми полями typedef будут отображаться в
# # документация области, в которой они определены (т.е. файл,
# # namespace, или групповая документация), при условии, что эта область задокументирована. Если задано
# # до NO, структуры, классы и объединения отображаются на отдельной странице (для HTML и
# # Man-страницы) или section (для LaTeX и RTF).
# # Значение по умолчанию: NO.
#
# INLINE_SIMPLE_STRUCTS = NO
#
# # Когда тег TYPEDEF_HIDES_STRUCT включен, typedef структуры, union или
# # Перечисление документируется как структура, объединение или перечисление с именем typedef. Так
# # typedef struct TypeS {} TypeT, появится в документации как struct
# # с именем TypeT. Когда эта опция отключена, typedef будет отображаться как член файла,
# # пространство имен или класс. И структура будет называться TypeS. Как правило, это может быть
# # полезно для кода C в случае, если соглашение о кодировании диктует, что все составные
# # Типы определяются типом, и ссылаются только на typedef, а не на имя тега.
# # Значение по умолчанию: NO.
#
# TYPEDEF_HIDES_STRUCT = NO
#
# # Размер кэша поиска символов можно задать с помощью LOOKUP_CACHE_SIZE. Этот
# # cache используется для разрешения символов с учетом их имени и области действия. Так как это может быть
# # ресурсоемкий процесс, и часто один и тот же символ появляется несколько раз в
# #, doxygen хранит кэш предварительно разрешенных символов. Если кэш слишком мал
# # doxygen станет медленнее. Если кэш слишком большой, память тратится впустую. Тем
# # Размер кэша определяется по формуле: 2^(16+LOOKUP_CACHE_SIZE). Допустимый диапазон
# # равно 0..9, по умолчанию 0, что соответствует размеру кэша 2^16=65536
# # символов. В конце запуска doxygen сообщит об использовании кэша и предложит
# # оптимальный размер кэша с точки зрения скорости.
# # Минимальное значение: 0, максимальное значение: 9, значение по умолчанию: 0.
#
# LOOKUP_CACHE_SIZE      = 0
#
# #---------------------------------------------------------------------------
# # Параметры конфигурации, связанные со сборкой
# #---------------------------------------------------------------------------
#
# # Если тег EXTRACT_ALL установлен в YES, doxygen будет предполагать все сущности в
# # документация документирована, даже если документация отсутствовала. Частный
# # члены класса и статические члены файла будут скрыты, если только
# # EXTRACT_PRIVATE соответственно EXTRACT_STATIC теги установлены в YES.
# # Замечание: Это также отключит предупреждения о недокументированных членах, которые
# # обычно создается, когда для параметра WARNINGS установлено значение YES.
# # Значение по умолчанию: NO.
#
# EXTRACT_ALL = YES
#
# # Если тег EXTRACT_PRIVATE установлен в YES, то все приватные члены класса будут
# # быть включенным в документацию.
# # Значение по умолчанию: NO.
#
# EXTRACT_PRIVATE = YES
#
# # Если тег EXTRACT_PACKAGE установлен в YES, все участники с пакетом или internal
# # scope будет включена в документацию.
# # Значение по умолчанию: NO.
#
# EXTRACT_PACKAGE = NO
#
# # Если тег EXTRACT_STATIC установлен в YES, то все статические члены файла будут
# # включен в документацию.
# # Значение по умолчанию: NO.
#
# EXTRACT_STATIC = YES
#
# # Если тег EXTRACT_LOCAL_CLASSES установлен в значение YES, классы (и структуры) определены
# # локально в исходных файлах будут включены в документацию. Если установлено значение NO
# # Включаются только классы, определенные в заголовочных файлах. Не оказывает никакого эффекта
# # для исходных текстов Java.
# # Значение по умолчанию: YES.
#
# EXTRACT_LOCAL_CLASSES = YES
#
# # Этот флаг полезен только для кода Objective-C. Если задано значение YES local methods,
# #, которые определены в разделе реализации, но не в интерфейсе,
# # включен в документацию. Если установлено значение NO, то в интерфейсе есть только методы
# # в комплекте.
# # Значение по умолчанию: NO.
#
# EXTRACT_LOCAL_METHODS = NO
#
# # Если этот флаг установлен в YES, члены анонимных пространств имён будут
# # extracted и отображаются в документации как пространство имен с именем
# # 'anonymous_namespace{file}', где file будет заменен на базовое имя
# # файл, содержащий анонимное пространство имён. По умолчанию анонимное пространство имен
# # скрыты.
# # Значение по умолчанию: NO.
#
# EXTRACT_ANON_NSPACES = YES
#
# # Если тег HIDE_UNDOC_MEMBERS установлен в YES, doxygen скроет все
# # недокументированные члены внутри документированных классов или файлов. Если установлено значение NO, эти
# # Участники будут включены в различные обзоры, но не будут иметь документации
# # сгенерирована. Эта опция не действует, если EXTRACT_ALL включена.
# # Значение по умолчанию: NO.
#
# HIDE_UNDOC_MEMBERS = NO
#
# # Если тег HIDE_UNDOC_CLASSES установлен в YES, doxygen скроет все
# # недокументированные классы, которые обычно видны в иерархии классов. Если задано
# # to NO эти классы будут включены в различные обзоры. Эта опция имеет
# # не действует, если EXTRACT_ALL включена.
# # Значение по умолчанию: NO.
#
# HIDE_UNDOC_CLASSES = NO
#
# # Если тег HIDE_FRIEND_COMPOUNDS установлен в YES, doxygen скроет всех друзей
# # (class|struct|union). Если установлено значение NO, эти объявления будут
# # включен в документацию.
# # Значение по умолчанию: NO.
#
# HIDE_FRIEND_COMPOUNDS = NO
#
# # Если тег HIDE_IN_BODY_DOCS установлен в YES, doxygen скроет любые
# # блоки документации, находящиеся внутри тела функции. Если установлено значение NO, эти
# # будут добавлены к блоку подробной документации функции.
# # Значение по умолчанию: NO.
#
# HIDE_IN_BODY_DOCS = NO
#
# # Тег INTERNAL_DOCS определяет, является ли документация, набранная после
# # \internal включена. Если тег установлен в NO, то документация
# # будут исключены. Задайте для него значение YES, чтобы включить внутреннюю документацию.
# # Значение по умолчанию: NO.
#
# INTERNAL_DOCS = NO
#
# # Если тег CASE_SENSE_NAMES установлен в NO, то doxygen будет генерировать только файл
# # имена строчными буквами. Если установлено значение YES, прописные буквы также
# # разрешено. Это полезно, если у вас есть классы или файлы, имена которых отличаются только
# # в случае, если ваша файловая система поддерживает чувствительные к регистру имена файлов. Виндоус
# # и пользователям Mac рекомендуется установить для этой опции значение NO.
# # Значение по умолчанию: system dependent.
#
# CASE_SENSE_NAMES = NO
#
# # Если тег HIDE_SCOPE_NAMES установлен в NO, то doxygen будет показывать члены с
# # их полные области видимости класса и пространства имен в документации. Если установлено значение YES, то
# # область видимости будет скрыта.
# # Значение по умолчанию: NO.
#
# HIDE_SCOPE_NAMES = NO
#
# # Если тег SHOW_INCLUDE_FILES установлен в YES, то doxygen поместит список
# # файлы, включенные файлом в документацию этого файла.
# # Значение по умолчанию: YES.
#
# SHOW_INCLUDE_FILES = YES
#
# # Если тег SHOW_GROUPED_MEMB_INC установлен в YES, то Doxygen добавит для каждого
# # grouped member an include statement to documentation, сообщая читателю
# # какой файл нужно включить, чтобы использовать элемент.
# # Значение по умолчанию: NO.
#
# SHOW_GROUPED_MEMB_INC = NO
#
# # Если тег FORCE_LOCAL_INCLUDES установлен в YES, то doxygen выведет в список include
# # файлы в документации с двойными кавычками, а не с острыми скобками.
# # Значение по умолчанию: NO.
#
# FORCE_LOCAL_INCLUDES = NO
#
# # Если тег INLINE_INFO установлен в YES, то тег [inline] вставляется в тег
# # Документация для встроенных членов.
# # Значение по умолчанию: YES.
#
# INLINE_INFO = YES
#
# # Если тег SORT_MEMBER_DOCS установлен в YES, то doxygen отсортирует
# # (подробная) документация по файлам и членам классов в алфавитном порядке по членам
# # имя. Если задано значение NO, элементы будут отображаться в порядке объявления.
# # Значение по умолчанию: YES.
#
# SORT_MEMBER_DOCS = YES
#
# # Если тег SORT_BRIEF_DOCS установлен в YES, то doxygen отсортирует бриф
# # описания файлов, пространств имен и членов классов в алфавитном порядке по элементам
# # имя. Если задано значение NO, элементы будут отображаться в порядке объявления. Обратите внимание, что
# # Это также повлияет на порядок классов в списке классов.
# # Значение по умолчанию: NO.
#
# SORT_BRIEF_DOCS = NO
#
# # Если тег SORT_MEMBERS_CTORS_1ST установлен в YES, то doxygen отсортирует
# # (краткая и подробная) документация членов класса, чтобы конструкторы и
# # деструкторы перечислены первыми. Если установлено значение NO, конструкторы будут отображаться в папке
# # соответствующие ордера, определяемые SORT_BRIEF_DOCS и SORT_MEMBER_DOCS.
# # Примечание: Если SORT_BRIEF_DOCS установлено в NO, эта опция игнорируется для сортировки брифов
# # Документация по участникам.
# # Примечание: Если SORT_MEMBER_DOCS установлено в NO, эта опция игнорируется при сортировке
# # подробная документация по участникам.
# # Значение по умолчанию: NO.
#
# SORT_MEMBERS_CTORS_1ST = NO
#
# # Если тег SORT_GROUP_NAMES установлен в YES, то doxygen отсортирует иерархию
# # названий групп в алфавитном порядке. Если установлено значение NO, имена групп будут
# # отображаются в определенном порядке.
# # Значение по умолчанию: NO.
#
# SORT_GROUP_NAMES = NO
#
# # Если тег SORT_BY_SCOPE_NAME установлен в YES, то список классов будет отсортирован по
# # полные имена, включая пространства имен. Если установлено значение NO, список классов будет
# # быть отсортированным только по имени класса, не включая часть пространства имен.
# # Замечание: Эта опция не очень полезна, если HIDE_SCOPE_NAMES установлено в YES.
# # Замечание: Эта опция применяется только к списку классов, а не к алфавитному
# # список.
# # Значение по умолчанию: NO.
#
# SORT_BY_SCOPE_NAME = NO
#
# # Если опция STRICT_PROTO_MATCHING включена, а doxygen не работает должным образом
# # разрешение типа всех параметров функции, он будет отклонять совпадение между
# # прототип и реализация функции-члена, даже если есть
# # только один кандидат или очевидно, какого кандидата выбрать, выполнив
# # простое совпадение строк. При отключении STRICT_PROTO_MATCHING doxygen по-прежнему будет
# # В таких случаях принимается совпадение между прототипом и реализацией.
# # Значение по умолчанию: NO.
#
# STRICT_PROTO_MATCHING = NO
#
# # Тег GENERATE_TODOLIST можно использовать для включения ( YES) или отключения ( NO)
# # список дел. Этот список создается путем помещения команд \todo в файл
# # документация.
# # Значение по умолчанию: YES.
#
# GENERATE_TODOLIST = YES
#
# # Тег GENERATE_TESTLIST можно использовать для включения ( YES) или отключения ( NO)
# # тестовый список. Этот список создается путем помещения команд \test в метод
# # документация.
# # Значение по умолчанию: YES.
#
# GENERATE_TESTLIST = YES
#
# # Тег GENERATE_BUGLIST может быть использован для включения ( YES) или отключения ( NO) ошибки
# # список. Этот список создается путем размещения команд \bug в документации.
# # Значение по умолчанию: YES.
#
# GENERATE_BUGLIST = YES
#
# # Тег GENERATE_DEPRECATEDLIST можно использовать для включения ( YES) или отключения ( NO)
# # Список устаревших. Этот список создается путем добавления команд \deprecated в
# # Документация.
# # Значение по умолчанию: YES.
#
# GENERATE_DEPRECATEDLIST= ДА
#
# # Тег ENABLED_SECTIONS можно использовать для включения условной документации
# # секции, помеченные \if <section_label> ... \endif и \cond <section_label>
# # ... \endcond блоков.
#
# ENABLED_SECTIONS       =
#
# # Тег MAX_INITIALIZER_LINES определяет максимальное количество строк, которое
# # начальное значение переменной или макроса / define может иметь для того, чтобы она появилась в
# # документация. Если инициализатор состоит из большего количества строк, чем указано здесь
# # он будет скрыт. Используйте значение 0, чтобы полностью скрыть инициализаторы. Тем
# # внешний вид значения отдельных переменных и макросов/определений может быть
# # управляется с помощью команд \showinitializer или \hideinitializer в
# # documentation независимо от этой настройки.
# # Минимальное значение: 0, максимальное значение: 10000, значение по умолчанию: 30.
#
# MAX_INITIALIZER_LINES  = 30
#
# # Установите тег SHOW_USED_FILES в NO, чтобы отключить список файлов, сгенерированных в
# # внизу документации классов и структур. Если установлено значение YES, список
# # укажет файлы, которые были использованы для создания документации.
# # Значение по умолчанию: YES.
#
# SHOW_USED_FILES = YES
#
# # Установите тег SHOW_FILES в значение NO, чтобы отключить генерацию страницы Файлы. Этот
# # удалит запись Files из Quick Index и из Folder Tree View
# # (если указано).
# # Значение по умолчанию: YES.
#
# SHOW_FILES = YES
#
# # Установите тег SHOW_NAMESPACES в значение NO, чтобы отключить генерацию пространств имен
# # страница. Это приведет к удалению записи Namespaces из Quick Index и из
# # Дерево папок (если указано).
# # Значение по умолчанию: YES.
#
# SHOW_NAMESPACES = YES
#
# # Тег FILE_VERSION_FILTER может быть использован для указания программы или скрипта, который
# # doxygen должен вызываться, чтобы получить текущую версию для каждого файла (обычно из
# # система контроля версий). Doxygen вызовет программу, выполнив (через
# # popen()) входной файл команды команды, где command - значение
# # FILE_VERSION_FILTER, а input-file - это имя предоставленного входного файла
# # от doxygen. Все, что программа записывает в стандартный вывод, используется в качестве файла
# # версия. Пример см. в документации.
#
# FILE_VERSION_FILTER    =
#
# # Тег LAYOUT_FILE может быть использован для указания файла макета, который будет анализироваться
# # от doxygen. Файл макета управляет глобальной структурой сгенерированного
# # Вывод файлов независимым от формата вывода. Создание файла макета
# # который представляет значения doxygen по умолчанию, запустите doxygen с опцией -l. Вы можете
# # опционально указать имя файла после опции, если опущено DoxygenLayout.xml
# # будет использоваться в качестве имени файла макета.
# #
# # Обратите внимание, что если вы запустите doxygen из каталога, содержащего файл с именем
# # DoxygenLayout.xml, doxygen будет разбирать его автоматически, даже если LAYOUT_FILE
# # остается пустым.
#
# LAYOUT_FILE            =
#
# # Тег CITE_BIB_FILES может быть использован для указания одного или нескольких стартовых файлов, содержащих
# # ссылочные определения. Это должен быть список файлов .bib. Файл .bib
# # автоматически добавляется, если опущено. Для этого необходим инструмент bibtex
# # для установки. Смотрите также http://en.wikipedia.org/wiki/BibTeX для получения дополнительной информации.
# # Для LaTeX стилем библиографии можно управлять с помощью
# # LATEX_BIB_STYLE. Чтобы использовать эту функцию, вам понадобятся bibtex и perl, доступные в
# # путь поиска. Не используйте имена файлов с пробелами, bibtex не сможет их обработать. Видеть
# # также \cite для получения информации о том, как создавать ссылки.
#
# CITE_BIB_FILES         =
#
# #---------------------------------------------------------------------------
# # Параметры конфигурации, связанные с предупреждениями и сообщениями о ходе выполнения
# #---------------------------------------------------------------------------
#
# # Тег QUIET можно использовать для включения/выключения сообщений, которые генерируются для
# # Стандартный вывод по doxygen. Если для параметра QUIET установлено значение YES, это означает, что
# # сообщения отключены.
# # Значение по умолчанию: NO.
#
# ТИХО = NO
#
# # Тег WARNINGS можно использовать для включения/выключения предупреждающих сообщений, которые
# # генерируется в стандартную ошибку ( stderr) doxygen. Если для параметра WARNINGS установлено значение YES
# # это означает, что предупреждения включены.
# #
# # Совет: Включите предупреждения при написании документации.
# # Значение по умолчанию: YES.
#
# ПРЕДУПРЕЖДЕНИЯ = YES
#
# # Если тег WARN_IF_UNDOCUMENTED установлен в YES, то doxygen будет генерировать
# # Предупреждения для недокументированных участников. Если EXTRACT_ALL установлено в значение YES, то этот флаг
# # будет автоматически отключен.
# # Значение по умолчанию: YES.
#
# WARN_IF_UNDOCUMENTED = YES
#
# # Если тег WARN_IF_DOC_ERROR установлен в YES, doxygen будет генерировать предупреждения для
# # возможные ошибки в документации, такие как недокументирование некоторых параметров
# # в документированной функции, или документирование параметров, которые не существуют, или использование
# # неправильно разметка команд.
# # Значение по умолчанию: YES.
#
# WARN_IF_DOC_ERROR = YES
#
# # Эта опция WARN_NO_PARAMDOC может быть включена для получения предупреждений для функций, которые
# # документированы, но не имеют документации по своим параметрам или возвращают
# # значение. Если установлено значение NO, doxygen будет предупреждать только о неправильном или неполном параметре
# #documentation, но не об отсутствии документации.
# # Значение по умолчанию: NO.
#
# WARN_NO_PARAMDOC = NO
#
# # Тег WARN_FORMAT определяет формат предупреждающих сообщений о том, что doxygen
# # может производить. Строка должна содержать $file, $line и $text теги, которые
# # будет заменено номером файла и строки, из которой пришло предупреждение
# # и текст предупреждения. Опционально формат может содержать $version, который
# # заменяется версией файла (если она может быть получена через
# # FILE_VERSION_FILTER)
# # Значение по умолчанию: $file:$line: $text.
#
# WARN_FORMAT            = "$file:$line: $text"
#
# # Тег WARN_LOGFILE может быть использован для указания файла, к которому относится предупреждение и ошибка
# # сообщения должны быть написаны. Если оставить пустым, вывод записывается в стандартный
# # ошибка (stderr).
#
# WARN_LOGFILE           =
#
# #---------------------------------------------------------------------------
# # Конфигурационные опции, относящиеся к входным файлам
# #---------------------------------------------------------------------------
#
# # Тег INPUT используется для указания файлов и/или каталогов, которые содержат
# # документированные исходные файлы. Вы можете ввести имена файлов, такие как myfile.cpp или
# # каталоги, такие как /usr/src/myproject. Разделите файлы или каталоги с помощью
# # пробелы.
# # Примечание: Если этот тег пуст, то выполняется поиск по текущему каталогу.
#
# ВХОДНЫЕ ДАННЫЕ =
#
# # Этот тег может быть использован для указания кодировки символов исходных файлов
# # который анализирует doxygen. Внутренне doxygen использует кодировку UTF-8. Использование Doxygen
# # libiconv (или iconv, встроенный в libc) для транскодирования. Смотрите libiconv
# # documentation (см.: http://www.gnu.org/software/libiconv) для получения списка
# # возможные кодировки.
# # Значение по умолчанию: UTF-8.
#
# INPUT_ENCODING         = UTF-8
#
# # Если значение тега INPUT содержит каталоги, вы можете использовать метод
# # FILE_PATTERNS для указания одного или нескольких шаблонов с подстановочными знаками (например, *.cpp и
# # *.h), чтобы отфильтровать исходные файлы в каталогах. Если оставить пустым,
# # тестируются следующие шаблоны:*.c, *.cc, *.cxx, *.cpp, *.c++, *.java, *.ii,
# # *.ixx, *.ipp, *.i++, *.inl, *.idl, *.ddl, *.odl, *.h, *.hh, *.hxx, *.hpp,
# # *.h++, *.cs, *.d, *.php, *.php4, *.php5, *.phtml, *.inc, *.m, *.markdown,
# # *.md, *.mm, *.dox, *.py, *.f90, *.f, *.for, *.tcl, *.vhd, *.vhdl, *.ucf,
# # *.qsf, *.as и *.js.
#
# FILE_PATTERNS          =
#
# # Тег RECURSIVE может быть использован для указания того, должны ли подкаталоги
# # также будет осуществляться поиск входных файлов.
# # Значение по умолчанию: NO.
#
# РЕКУРСИВНЫЙ = YES
#
# # Тег EXCLUDE может быть использован для указания файлов и/или каталогов, которые должны быть
# # исключен из исходных файлов INPUT. Таким образом, вы можете легко исключить
# # из дерева каталогов, корень которого указан с помощью тега INPUT.
# #
# # Обратите внимание, что относительные пути относятся к каталогу, из которого doxygen
# # выполнить.
#
# EXCLUDE                =
#
# # Тег EXCLUDE_SYMLINKS может быть использован для выбора файлов или
# # каталоги, которые являются символьными ссылками (особенность файловой системы Unix), исключаются
# # из входных данных.
# # Значение по умолчанию: NO.
#
# EXCLUDE_SYMLINKS = NO
#
# # Если значение тега INPUT содержит каталоги, вы можете использовать метод
# # EXCLUDE_PATTERNS для указания одного или нескольких шаблонов с подстановочными знаками для исключения
# # некоторые файлы из этих каталогов.
# #
# # Обратите внимание, что подстановочные знаки сопоставляются с файлом с абсолютным путем, поэтому
# # исключить все тестовые каталоги, например, использовать шаблон */test/*
#
# EXCLUDE_PATTERNS       =
#
# # Тег EXCLUDE_SYMBOLS может быть использован для указания одного или нескольких имен символов
# # (пространства имен, классы, функции и т.д.), которые должны быть исключены из
# # Вывод. Имя символа может быть полным именем, словом или, если
# # используется подстановочный знак *, подстрока. Примеры: ANamespace, AClass,
# # AClass::ANamespace, ANamespace::*Test
# #
# # Обратите внимание, что подстановочные знаки сопоставляются с файлом с абсолютным путем, поэтому
# # исключить все тестовые каталоги, использовать шаблон */test/*
#
# EXCLUDE_SYMBOLS        =
#
# # Тег EXAMPLE_PATH может быть использован для указания одного или нескольких файлов или каталогов
# #, которые содержат примеры фрагментов кода, которые включены (см. \include
# #).
#
# EXAMPLE_PATH           =
#
# # Если значение тега EXAMPLE_PATH содержит каталоги, вы можете использовать метод
# # EXAMPLE_PATTERNS для указания одного или нескольких шаблонов с подстановочными знаками (например, *.cpp и
# # *.h), чтобы отфильтровать исходные файлы в каталогах. Если оставить пустым, все
# # файлы включены.
#
# EXAMPLE_PATTERNS       =
#
# # Если тег EXAMPLE_RECURSIVE установлен в YES, то подкаталоги будут
# # Поиск входных файлов для использования с командами \include или \dontinclude
# # независимо от значения тега RECURSIVE.
# # Значение по умолчанию: NO.
#
# EXAMPLE_RECURSIVE = NO
#
# # Тег IMAGE_PATH может быть использован для указания одного или нескольких файлов или каталогов
# #, которые содержат изображения, которые должны быть включены в документацию (см.
# # \image).
#
# IMAGE_PATH             =
#
# # Тег INPUT_FILTER может быть использован для указания программы, которую doxygen должен
# # вызов для фильтрации для каждого входного файла. Doxygen вызовет программу фильтрации
# # выполнив (через popen()) команду:
# #
# # <filter> <input-file>
# #
# # где <filter> — значение тега INPUT_FILTER, а <input-file> — значение
# # имя входного файла. Затем Doxygen будет использовать выход, который фильтр
# # Программа записывает в стандартный вывод. Если указан FILTER_PATTERNS, то этот тег
# # будет проигнорировано.
# #
# # Обратите внимание, что фильтр не должен добавлять или удалять строки; Он применяется перед
# # код сканируется, но не при генерации выходного кода. Если добавлены строки
# # или удалены, якоря будут размещены неправильно.
#
# INPUT_FILTER           =
#
# # Тег FILTER_PATTERNS может быть использован для указания фильтров для каждого шаблона файла
# # базис. Doxygen сравнит имя файла с каждым шаблоном и применит метод
# # фильтр, если есть совпадение. Фильтры представляют собой список вида: pattern=filter
# # (например, *.cpp=my_cpp_filter). Дополнительную информацию о том, как это сделать, см. в INPUT_FILTER
# # используются фильтры. Если FILTER_PATTERNS тег пуст или если ни один из тегов
# # шаблоны совпадают с именем файла, INPUT_FILTER применяется.
#
# FILTER_PATTERNS        =
#
# # Если тег FILTER_SOURCE_FILES установлен в YES, входной фильтр (если он установлен с помощью
# # INPUT_FILTER ) также будет использоваться для фильтрации входных файлов, которые используются для
# # создание исходных файлов для просмотра (т.е. когда SOURCE_BROWSER установлено в YES).
# # Значение по умолчанию: NO.
#
# FILTER_SOURCE_FILES = NO
#
# # Тег FILTER_SOURCE_PATTERNS можно использовать для указания исходных фильтров для каждого файла
# # паттерн. Шаблон переопределит настройку для FILTER_PATTERN (если таковые имеются) и
# # также можно отключить фильтрацию источников для конкретного паттерна с помощью
# # *.ext= (т.е. без именования фильтра).
# # Этот тег требует, чтобы FILTER_SOURCE_FILES тега был установлен в YES.
#
# FILTER_SOURCE_PATTERNS =
#
# # Если тег USE_MDFILE_AS_MAINPAGE ссылается на имя markdown-файла, который
# # является частью входных данных, его содержимое будет размещено на главной странице
# # (index.html). Это может быть полезно, если у вас есть проект, например, на GitHub
# # и хотим повторно использовать вводную страницу также для вывода doxygen.
#
# USE_MDFILE_AS_MAINPAGE =
#
# #---------------------------------------------------------------------------
# # Параметры конфигурации, связанные с просмотром исходного кода
# #---------------------------------------------------------------------------
#
# # Если тег SOURCE_BROWSER установлен в YES, то список исходных файлов будет
# # сгенерировано. Документированные сущности будут сопровождаться перекрестными ссылками на эти источники.
# #
# # Замечание: Чтобы избавиться от всего исходного кода в сгенерированном выводе, убедитесь, что
# # также VERBATIM_HEADERS установлено в NO.
# # Значение по умолчанию: NO.
#
# SOURCE_BROWSER = YES
#
# # Установка тега INLINE_SOURCES в YES будет включать в себя тело функций,
# # классов и перечислений прямо в документацию.
# # Значение по умолчанию: NO.
#
# INLINE_SOURCES = YES
#
# # Установка тега STRIP_CODE_COMMENTS в YES укажет doxygen скрыть любые
# # специальные блоки комментариев из сгенерированных фрагментов исходного кода. Обычный C, C++ и
# # Комментарии к Fortran всегда будут оставаться видимыми.
# # Значение по умолчанию: YES.
#
# STRIP_CODE_COMMENTS = YES
#
# # Если тег REFERENCED_BY_RELATION установлен в YES, то для каждого документированного
# # будут перечислены все документированные функции, ссылающиеся на нее.
# # Значение по умолчанию: NO.
#
# REFERENCED_BY_RELATION = YES
#
# # Если тег REFERENCES_RELATION установлен в YES, то для каждой документированной функции
# # Будут перечислены все документированные сущности, вызванные/используемые этой функцией.
# # Значение по умолчанию: NO.
#
# REFERENCES_RELATION = YES
#
# # Если тег REFERENCES_LINK_SOURCE установлен в YES и SOURCE_BROWSER тег установлен
# # в YES, то гиперссылки из функций в REFERENCES_RELATION и
# # REFERENCED_BY_RELATION списков будут ссылаться на исходный код. В противном случае они будут
# # ссылка на документацию.
# # Значение по умолчанию: YES.
#
# REFERENCES_LINK_SOURCE = YES
#
# # Если SOURCE_TOOLTIPS включен (по умолчанию), то наведение гиперссылки в поле
# # исходный код покажет всплывающую подсказку с дополнительной информацией, такой как prototype,
# # краткое описание и ссылки на определение и документацию. Так как это
# # сделает HTML-файл больше, а загрузка больших файлов немного медленнее, вы
# # можно отключить эту функцию.
# # Значение по умолчанию: YES.
# # Этот тег требует, чтобы SOURCE_BROWSER тега был установлен в YES.
#
# SOURCE_TOOLTIPS = YES
#
# # Если тег USE_HTAGS установлен в YES, то ссылки на исходный код будут
# # указать HTML-код, сгенерированный инструментом htags(1) вместо встроенного doxygen
# # исходный браузер. Инструмент htags является частью глобальной системы тегов исходного кода GNU
# # (см. http://www.gnu.org/software/global/global.html). Вам понадобится версия
# # 4.8.6 или выше.
# #
# # Чтобы использовать его, выполните следующие действия:
# # - Установить последнюю версию глобального
# # - Включить SOURCE_BROWSER и USE_HTAGS в конфигурационном файле
# # - Убедитесь, что INPUT указывает на корень дерева исходных текстов
# # - Запустить doxygen как обычно
# #
# # Doxygen будет вызывать htags (а тот, в свою очередь, вызовет gtags), так что эти
# # Инструменты должны быть доступны из командной строки (т.е. в пути поиска).
# #
# # Результат: вместо исходного браузера, сгенерированного doxygen, ссылки на
# # Исходный код теперь будет указывать на вывод htags.
# # Значение по умолчанию: NO.
# # Этот тег требует, чтобы SOURCE_BROWSER тега был установлен в YES.
#
# USE_HTAGS = NO
#
# # Если VERBATIM_HEADERS тег установлен YES, то doxygen сгенерирует
# # дословная копия заголовочного файла для каждого класса, для которого включено
# # указано. Установите значение NO, чтобы отключить эту функцию.
# # Смотрите также: Раздел \class.
# # Значение по умолчанию: YES.
#
# VERBATIM_HEADERS = YES
#
#
# #---------------------------------------------------------------------------
# # Параметры конфигурации, связанные с алфавитным индексом класса
# #---------------------------------------------------------------------------
#
# # Если тег ALPHABETICAL_INDEX установлен в YES, то алфавитный индекс всех
# # будут сгенерированы составные элементы. Включите эту опцию, если проект содержит много
# # классы, структуры, объединения или интерфейсы.
# # Значение по умолчанию: YES.
#
# ALPHABETICAL_INDEX = YES
#
# # Тег COLS_IN_ALPHA_INDEX можно использовать для указания количества столбцов в
# # который будет разбит алфавитный индексный список.
# # Минимальное значение: 1, максимальное значение: 20, значение по умолчанию: 5.
# # Этот тег требует, чтобы тег ALPHABETICAL_INDEX был установлен в YES.
#
# COLS_IN_ALPHA_INDEX    = 5
#
# # В случае, если все классы в проекте начинаются с общего префикса, все классы будут
# # помещаться под тем же заголовком в алфавитном указателе. Тег IGNORE_PREFIX
# # может использоваться для указания префикса (или списка префиксов), который следует игнорировать
# # при генерации заголовков индекса.
# # Этот тег требует, чтобы тег ALPHABETICAL_INDEX был установлен в YES.
#
# IGNORE_PREFIX          =
#
# #---------------------------------------------------------------------------
# # Параметры конфигурации, связанные с выводом HTML
# #---------------------------------------------------------------------------
#
# # Если тег GENERATE_HTML установлен в YES, doxygen сгенерирует HTML-вывод
# # Значение по умолчанию: YES.
#
# GENERATE_HTML = YES
#
# # Тег HTML_OUTPUT используется для указания того, куда будут помещены HTML-документы. Если
# # введен относительный путь, значение OUTPUT_DIRECTORY будет поставлено перед
# # это.
# # Каталог по умолчанию: html.
# # Этот тег требует, чтобы GENERATE_HTML тега был установлен в YES.
#
# HTML_OUTPUT            = html
#
# # Тег HTML_FILE_EXTENSION может быть использован для указания расширения файла для каждого
# # сгенерированная HTML-страница (например: .htm, .php, .asp).
# # Значение по умолчанию: .html.
# # Этот тег требует, чтобы GENERATE_HTML тега был установлен в YES.
#
# HTML_FILE_EXTENSION    = .html
#
# # Тег HTML_HEADER может быть использован для указания пользовательского HTML-файла заголовка для
# # каждая сгенерированная HTML-страница. Если тег оставить пустым, doxygen сгенерирует
# # стандартный заголовок.
# #
# # Чтобы получить валидный HTML, заголовочный файл, который включает в себя любые скрипты и таблицы стилей
# # что нужно doxygen, что зависит от используемых параметров конфигурации (например,
# # настройка GENERATE_TREEVIEW). Настоятельно рекомендуется начать с
# # заголовок по умолчанию с использованием
# # doxygen -w html new_header.html new_footer.html new_stylesheet.css
# # ВашКонфигурационныйФайл
# #, а затем измените файл new_header.html. Смотрите также раздел «Использование Doxygen»
# # для получения информации о том, как сгенерировать заголовок по умолчанию, который doxygen обычно
# # использования.
# # Замечание: Заголовок может быть изменен, поэтому обычно приходится заново генерировать
# # Заголовок по умолчанию при обновлении до более новой версии dOxygen. Для описания
# # возможных маркеров и названий блоков см. в документации.
# # Этот тег требует, чтобы GENERATE_HTML тега был установлен в YES.
#
# HTML_HEADER            =
#
# # Тег HTML_FOOTER может быть использован для указания пользовательского HTML-футера для каждого
# # сгенерированная HTML-страница. Если тег оставить пустым, doxygen сгенерирует стандартный
# # нижний колонтитул. Дополнительные сведения о том, как создать значение по умолчанию, см. в HTML_HEADER
# # footer и какие специальные команды можно использовать внутри футера. Смотрите также
# # раздел "Doxygen usage" для получения информации о том, как сгенерировать нижний колонтитул по умолчанию
# # который обычно использует doxygen.
# # Этот тег требует, чтобы GENERATE_HTML тега был установлен в YES.
#
# HTML_FOOTER            =
#
# # Тег HTML_STYLESHEET может быть использован для указания пользовательского каскадного стиля
# # лист, который используется каждой HTML-страницей. Его можно использовать для тонкой настройки внешнего вида
# # HTML-вывод. Если оставить пустым, doxygen сгенерирует таблицу стилей по умолчанию.
# # Смотрите также раздел "Doxygen usage" для получения информации о том, как сгенерировать стиль
# # Лист, который обычно использует Doxygen.
# # Примечание: Рекомендуется использовать HTML_EXTRA_STYLESHEET вместо этого тега, так как
# # он более надежен и этот тег (HTML_STYLESHEET) в будущем станет
# # устарело.
# # Этот тег требует, чтобы GENERATE_HTML тега был установлен в YES.
#
# HTML_STYLESHEET        =
#
# # Тег HTML_EXTRA_STYLESHEET может быть использован для указания дополнительного user-
# # определенная каскадная таблица стилей, которая включается после стандартных таблиц стилей
# # Создано doxygen. Используя эту опцию, можно отменять определенные аспекты стиля.
# # Это предпочтительнее, чем использование HTML_STYLESHEET, так как оно не заменяет
# # стандартная таблица стилей и, следовательно, более устойчива к будущим обновлениям.
# # Doxygen скопирует файл таблицы стилей в выходной каталог. Для примера
# # см. документацию.
# # Этот тег требует, чтобы GENERATE_HTML тега был установлен в YES.
#
# HTML_EXTRA_STYLESHEET  =
#
# # Тег HTML_EXTRA_FILES может быть использован для указания одного или нескольких дополнительных изображений или
# # другие исходные файлы, которые должны быть скопированы в выходной каталог HTML. Заметка
# # что эти файлы будут скопированы в базовый выходной каталог HTML. Используйте кнопку
# # $relpath^ в файлах HTML_HEADER и/или HTML_FOOTER для загрузки
# # файлов. В HTML_STYLESHEET файле используйте только имя файла. Также обратите внимание, что
# # файлы будут скопированы как есть; Команды или маркеры недоступны.
# # Этот тег требует, чтобы GENERATE_HTML тега был установлен в YES.
# #
# # опция конфигурации doxygen HTML_EXTRA_FILES позволяет копировать дополнительные файлы в корень
# # документации. Для копирования файла вы должны указать следующее:
# #
# # HTML_EXTRA_FILES = ../documents/xxx.pdf
# # Это поместит xxx.pdf в корень вашей HTML-документации, поэтому вам, вероятно, придется изменить ссылку на:
# #
# # <a href="xxx.pdf" target="_blank"><b>Overview</b></a>
#
# HTML_EXTRA_FILES       =
#
# # Тег HTML_COLORSTYLE_HUE управляет цветом HTML-вывода. Кислород
# # настроит цвета в таблице стилей и фоновых изображениях в соответствии с
# # этот цвет. Оттенок задается в виде угла на цветовом круге, см.
# # http://en.wikipedia.org/wiki/Hue для получения дополнительной информации. Например, значение
# # 0 - красный, 60 - желтый, 120 - зеленый, 180 - голубой, 240 - синий, 300
# # фиолетовый, а 360 снова красный.
# # Минимальное значение: 0, максимальное значение: 359, значение по умолчанию: 220.
# # Этот тег требует, чтобы GENERATE_HTML тега был установлен в YES.
#
# HTML_COLORSTYLE_HUE    = 220
#
# # Тег HTML_COLORSTYLE_SAT управляет чистотой (или насыщенностью) цветов
# # в выводе HTML. При значении 0 выходные данные будут использовать только оттенки серого. A
# # Значение 255 даст наиболее яркие цвета.
# # Минимальное значение: 0, максимальное значение: 255, значение по умолчанию: 100.
# # Этот тег требует, чтобы GENERATE_HTML тега был установлен в YES.
#
# HTML_COLORSTYLE_SAT    = 100
#
# # Тег HTML_COLORSTYLE_GAMMA управляет гамма-коррекцией, применяемой к
# # компонент яркости цветов в выводе HTML. Значения ниже 100
# # постепенно делать вывод светлее, в то время как значения выше 100 делают вывод
# # темнее. Значение, деленное на 100, является фактической примененной гаммой, поэтому 80 представляет собой
# # гамма 0.8, Значение 220 соответствует гамме 2.2, а 100 - нет
# # изменить гамму.
# # Минимальное значение: 40, максимальное значение: 240, значение по умолчанию: 80.
# # Этот тег требует, чтобы GENERATE_HTML тега был установлен в YES.
#
# HTML_COLORSTYLE_GAMMA  = 80
#
# # Если тег HTML_TIMESTAMP установлен в YES, то нижний колонтитул каждого сгенерированного HTML
# # page будет содержать дату и время, когда страница была сгенерирована. Установка этого параметра
# # в NO может помочь при сравнении выходных данных нескольких запусков.
# # Значение по умолчанию: YES.
# # Этот тег требует, чтобы GENERATE_HTML тега был установлен в YES.
#
# HTML_TIMESTAMP = YES
#
# # Если тег HTML_DYNAMIC_SECTIONS установлен в YES, то сгенерированный HTML
# # будет содержать разделы, которые можно скрыть и показать после
# # (например, графы), которые пользователь по желанию может впоследствии раскрыть
#
# HTML_DYNAMIC_SECTIONS = NO
#
# # С помощью HTML_INDEX_NUM_ENTRIES можно контролировать желаемое количество записей
# # изначально отображается в различных древовидных структурированных индексах; Пользователь может развернуть
# # и динамически сворачивать записи позже. Doxygen расширит дерево до
# # такой уровень, чтобы было видно не более указанного количества записей (если только
# # полностью свернутое дерево уже превышает это количество). Таким образом, установка количества
# # Записи 1 по умолчанию создадут полное свернутое дерево. 0 — специальное значение
# #, представляющее бесконечное количество записей и приведёт к полному развёрнутому
# # дерево по умолчанию.
# # Минимальное значение: 0, максимальное значение: 9999, значение по умолчанию: 100.
# # Этот тег требует, чтобы GENERATE_HTML тега был установлен в YES.
#
# HTML_INDEX_NUM_ENTRIES = 100
#
# # Если тег GENERATE_DOCSET установлен в YES, дополнительные индексные файлы будут
# # сгенерирован, который может быть использован в качестве входных данных для интегрированной разработки Apple Xcode 3
# # (см.: http://developer.apple.com/tools/xcode/), вводимый с помощью
# # OSX 10.5 (Leopard). Чтобы создать набор документации, doxygen сгенерирует
# # Makefile в выходном каталоге HTML. Запуск make создаст docset в
# # что каталог и запуск make install установит docset в
# # ~/Library/Developer/Shared/Documentation/DocSets, чтобы Xcode нашел его по адресу
# # Запуск. Смотрите http://developer.apple.com/tools/creatingdocsetswithdoxygen.html
# # для получения дополнительной информации.
# # Значение по умолчанию: NO.
# # Этот тег требует, чтобы GENERATE_HTML тега был установлен в YES.
#
# GENERATE_DOCSET = NO
#
# # Этот тег определяет имя ленты docset. Канал документации предоставляет
# # зонтик, под которым несколько наборов документации от одного провайдера
# # (например, компания или набор продуктов) могут быть сгруппированы.
# # Значение по умолчанию: Doxygen generated docs.
# # Этот тег требует, чтобы GENERATE_DOCSET тега был установлен в YES.
#
# DOCSET_FEEDNAME = "Документы, сгенерированные Doxygen"
#
# # Этот тег указывает строку, которая должна однозначно идентифицировать документацию
# # набор пакетов. Это должна быть обратная строка стиля доменного имени, например,
# # com.mycompany.MyDocSet. Doxygen добавит .docset к имени.
# # Значение по умолчанию: org.doxygen.Project.
# # Этот тег требует, чтобы GENERATE_DOCSET тега был установлен в YES.
#
# DOCSET_BUNDLE_ID       = org.doxygen.Project
#
# # Тег DOCSET_PUBLISHER_ID указывает строку, которая должна однозначно идентифицировать
# # издатель документации. Это должен быть обратный стиль доменного имени
# # строка, например, .com.mycompany.MyDocSet.documentation.
# # Значение по умолчанию: org.doxygen.Publisher.
# # Этот тег требует, чтобы GENERATE_DOCSET тега был установлен в YES.
#
# DOCSET_PUBLISHER_ID    = org.doxygen.Publisher
#
# # Тег DOCSET_PUBLISHER_NAME идентифицирует издателя документации.
# # Значение по умолчанию: Publisher.
# # Этот тег требует, чтобы GENERATE_DOCSET тега был установлен в YES.
#
# DOCSET_PUBLISHER_NAME = Издатель
#
# # Если тег GENERATE_HTMLHELP установлен в YES, то doxygen генерирует три
# # дополнительные индексные HTML-файлы: index.hhp, index.hhc и index.hhk. Тем
# # index.hhp — это файл проекта, который может быть прочитан с помощью Microsoft HTML Help Workshop
# # (см.: http://www.microsoft.com/en-us/download/details.aspx?id=21138) на
# # Окна.
# #
# # В HTML Help Workshop есть компилятор, который может конвертировать весь вывод HTML
# # сгенерирован doxygen в один скомпилированный HTML-файл (.chm). Скомпилированный HTML
# # файлы теперь используются в качестве формата справки Windows 98 и заменят старый
# # Формат справки Windows (.hlp) на всех платформах Windows в будущем. Сжатый
# # HTML-файлы также содержат индекс, оглавление, и вы можете искать
# # слова в документации. Воркшоп HTML также содержит средство просмотра для
# # сжатые HTML-файлы.
# # Значение по умолчанию: NO.
# # Этот тег требует, чтобы GENERATE_HTML тега был установлен в YES.
#
# GENERATE_HTMLHELP = NO
#
# # Тег CHM_FILE может быть использован для указания имени файла результирующего .chm
# # файл. Вы можете добавить путь перед файлом, если результат не должен быть
# # записывается в выходной каталог html.
# # Этот тег требует, чтобы GENERATE_HTMLHELP тега был установлен в YES.
#
# CHM_FILE               =
#
# # Тег HHC_LOCATION может быть использован для указания местоположения (абсолютный путь
# # включая имя файла) компилятора HTML-справки ( hhc.exe). Если не пустое
# # doxygen попытается запустить HTML-компилятор справки на сгенерированном index.hhp.
# # Файл должен быть указан с полным путем.
# # Этот тег требует, чтобы GENERATE_HTMLHELP тега был установлен в YES.
#
# HHC_LOCATION           =
#
# # Флаг GENERATE_CHI определяет, будет ли сгенерирован отдельный индексный файл .chi (
# # YES) или что он должен быть включен в главный файл .chm ( NO).
# # Значение по умолчанию: NO.
# # Этот тег требует, чтобы GENERATE_HTMLHELP тега был установлен в YES.
#
# GENERATE_CHI = NO
#
# # CHM_INDEX_ENCODING используется для кодирования индекса HtmlHelp ( hhk), контента ( hhc)
# # и содержимое файла проекта.
# # Этот тег требует, чтобы GENERATE_HTMLHELP тега был установлен в YES.
#
# CHM_INDEX_ENCODING     =
#
# # Флаг BINARY_TOC определяет, будет ли сгенерировано двоичное оглавление (
# # YES) или обычное оглавление ( NO) в файле .chm. Кроме того,
# # включает кнопки Назад и Далее.
# # Значение по умолчанию: NO.
# # Этот тег требует, чтобы GENERATE_HTMLHELP тега был установлен в YES.
#
# BINARY_TOC = NO
#
# # Флаг TOC_EXPAND может быть установлен в YES, чтобы добавить дополнительные элементы для участников группы в
# # оглавление справочной документации HTML и в древовидное представление.
# # Значение по умолчанию: NO.
# # Этот тег требует, чтобы GENERATE_HTMLHELP тега был установлен в YES.
#
# TOC_EXPAND = NO
#
# # Если тег GENERATE_QHP установлен в YES и оба QHP_NAMESPACE и
# # QHP_VIRTUAL_FOLDER будет сгенерирован дополнительный индексный файл, который
# # может быть использован в качестве входных данных для Qt qhelpgenerator для генерации Qt Compressed Help
# # (.qch) сгенерированной HTML-документации.
# # Значение по умолчанию: NO.
# # Этот тег требует, чтобы GENERATE_HTML тега был установлен в YES.
#
# GENERATE_QHP = NO
#
# # Если указан тег QHG_LOCATION, то тег QCH_FILE может быть использован для указания
# # имя результирующего файла .qch. Указанный путь является относительным к
# # выходная HTML-папка.
# # Этот тег требует, чтобы GENERATE_QHP тега был установлен в YES.
#
# QCH_FILE               =
#
# # Тег QHP_NAMESPACE определяет пространство имён, которое будет использоваться при генерации Qt Help
# # Выходные данные проекта. Для получения дополнительной информации, пожалуйста, обратитесь к Qt Help Project / Namespace
# # (см.: http://qt-project.org/doc/qt-4.8/qthelpproject.html#namespace).
# # Значение по умолчанию: org.doxygen.Project.
# # Этот тег требует, чтобы GENERATE_QHP тега был установлен в YES.
#
# QHP_NAMESPACE          = org.doxygen.Project
#
# # Тег QHP_VIRTUAL_FOLDER определяет пространство имен, которое будет использоваться при генерации Qt
# # Справка Выходные данные проекта. Для получения дополнительной информации, пожалуйста, обратитесь к Qt Help Project / Virtual
# # Папки (см.: http://qt-project.org/doc/qt-4.8/qthelpproject.html#virtual-
# # папки).
# # Значение по умолчанию: doc.
# # Этот тег требует, чтобы GENERATE_QHP тега был установлен в YES.
#
# QHP_VIRTUAL_FOLDER     = doc
#
# # Если установлен тег QHP_CUST_FILTER_NAME, то он указывает имя пользовательского тега
# # фильтр для добавления. Для получения дополнительной информации, пожалуйста, обратитесь к Qt Help Project / Custom
# # Фильтры (см.: http://qt-project.org/doc/qt-4.8/qthelpproject.html#custom-
# # фильтры).
# # Этот тег требует, чтобы GENERATE_QHP тега был установлен в YES.
#
# QHP_CUST_FILTER_NAME   =
#
# # Тег QHP_CUST_FILTER_ATTRS задает список атрибутов
# # пользовательский фильтр для добавления. Для получения дополнительной информации, пожалуйста, обратитесь к Qt Help Project / Custom
# # Фильтры (см.: http://qt-project.org/doc/qt-4.8/qthelpproject.html#custom-
# # фильтры).
# # Этот тег требует, чтобы GENERATE_QHP тега был установлен в YES.
#
# QHP_CUST_FILTER_ATTRS  =
#
# # Тег QHP_SECT_FILTER_ATTRS задает список атрибутов this
# # совпадает секция фильтра проекта. Qt Help Project / Атрибуты фильтра (см.:
# # http://qt-project.org/doc/qt-4.8/qthelpproject.html#filter-attributes).
# # Этот тег требует, чтобы GENERATE_QHP тега был установлен в YES.
#
# QHP_SECT_FILTER_ATTRS  =
#
# # Тег QHG_LOCATION может быть использован для указания местоположения
# # qhelpgenerator. Если непустой doxygen попытается запустить qhelpgenerator на
# # сгенерированный файл .qhp.
# # Этот тег требует, чтобы GENERATE_QHP тега был установлен в YES.
#
# QHG_LOCATION           =
#
# # Если тег GENERATE_ECLIPSEHELP установлен в YES, дополнительные индексные файлы будут
# # сгенерированы, вместе с HTML-файлами они образуют справочный плагин Eclipse. Кому
# # Установите этот плагин и сделайте его доступным в меню содержимого справки в
# # Eclipse, содержимое каталога, содержащего файлы HTML и XML
# # для копирования в каталог плагинов Eclipse. Имя каталога
# # в каталоге plugins должно совпадать со значением ECLIPSE_DOC_ID.
# # После копирования Eclipse необходимо перезапустить, прежде чем появится справка.
# # Значение по умолчанию: NO.
# # Этот тег требует, чтобы GENERATE_HTML тега был установлен в YES.
#
# GENERATE_ECLIPSEHELP = NO
#
# # Уникальный идентификатор справочного плагина Eclipse. При установке плагина
# # имя каталога, содержащего файлы HTML и XML, также должно иметь следующее
# # имя. Каждый набор документации должен иметь свой идентификатор.
# # Значение по умолчанию: org.doxygen.Project.
# # Этот тег требует, чтобы GENERATE_ECLIPSEHELP тега был установлен в YES.
#
# ECLIPSE_DOC_ID         = org.doxygen.Project
#
# # Если вы хотите получить полный контроль над макетом сгенерированных HTML-страниц, это может быть
# # необходимо отключить индекс и заменить его на свой. Тем
# # DISABLE_INDEX тег можно использовать для включения/выключения сжатого индекса (вкладок) вверху
# # каждой HTML-страницы. Значение NO включает индекс, а значение YES отключает
# # это. Так как вкладки в индексе содержат ту же информацию, что и навигация
# # tree, вы можете установить эту опцию в YES, если вы также установили GENERATE_TREEVIEW в YES.
# # Значение по умолчанию: NO.
# # Этот тег требует, чтобы GENERATE_HTML тега был установлен в YES.
# #
# # Отключает отображение меню с вкладками
#
# DISABLE_INDEX = YES
#
# # Тег GENERATE_TREEVIEW используется для того, чтобы указать, является ли древовидный индекс
# # должна быть сгенерирована структура для отображения иерархической информации. Если тег
# # установлено в YES, будет сгенерирована боковая панель, содержащая древовидный
# # структура индекса (аналогичная той, которая генерируется для HTML Help). Для этого
# # для работы требуется браузер, поддерживающий JavaScript, DHTML, CSS и фреймы
# # (т.е. любой современный браузер). Пользователям Windows, вероятно, лучше использовать
# # Справочная функция HTML. С помощью пользовательских таблиц стилей (см. HTML_EXTRA_STYLESHEET) можно
# # Дальнейшая тонкая настройка внешнего вида индекса. В качестве примера можно привести стиль по умолчанию
# # В листе, сгенерированном doxygen, есть пример, который показывает, как поместить изображение в
# # корень дерева вместо PROJECT_NAME. Так как дерево в основном имеет
# # та же информация, что и индекс табуляции, вы можете рассмотреть возможность установки
# # DISABLE_INDEX значение YES при включении этой опции.
# # Значение по умолчанию: NO.
# # Этот тег требует, чтобы GENERATE_HTML тега был установлен в YES.
# #
# # Показывает отображать или нет иерархическое дерево
#
# GENERATE_TREEVIEW = YES
#
# # Тег ENUM_VALUES_PER_LINE может быть использован для установки количества значений перечисления, которые
# # doxygen будет сгруппирован в одну строку в сгенерированной HTML-документации.
# #
# # Обратите внимание, что значение 0 полностью подавит появление значений перечисления
# # в разделе обзора.
# # Минимальное значение: 0, максимальное значение: 20, значение по умолчанию: 4.
# # Этот тег требует, чтобы GENERATE_HTML тега был установлен в YES.
#
# ENUM_VALUES_PER_LINE   = 4
#
# # Если древовидное представление включено (см. GENERATE_TREEVIEW), то этот тег можно использовать
# # для установки начальной ширины (в пикселях) фрейма, в котором отображается дерево.
# # Минимальное значение: 0, максимальное значение: 1500, значение по умолчанию: 250.
# # Этот тег требует, чтобы GENERATE_HTML тега был установлен в YES.
#
# TREEVIEW_WIDTH         = 250
#
# # Когда опция EXT_LINKS_IN_WINDOW установлена в YES, doxygen будет открывать ссылки на
# # внешние символы, импортируемые через файлы тегов в отдельном окне.
# # Значение по умолчанию: NO.
# # Этот тег требует, чтобы GENERATE_HTML тега был установлен в YES.
#
# EXT_LINKS_IN_WINDOW = NO
#
# # Используйте этот тег для изменения размера шрифта формул LaTeX, включенных в качестве изображений в
# # HTML-документация. При изменении размера шрифта после успешного выполнения
# # doxygen run вам нужно вручную удалить все form_*.png изображения из HTML
# # output, чтобы принудительно сгенерировать их.
# # Минимальное значение: 8, максимальное значение: 50, значение по умолчанию: 10.
# # Этот тег требует, чтобы GENERATE_HTML тега был установлен в YES.
#
# FORMULA_FONTSIZE       = 10
#
# # Используйте тег FORMULA_TRANPARENT, чтобы определить, будут ли изображения
# # генерируются для формул прозрачные PNG. Прозрачные PNG не являются
# # корректно поддерживаются для IE 6.0, но поддерживаются во всех современных браузерах.
# #
# # Обратите внимание, что при изменении этой опции вам нужно удалить все файлы form_*.png в
# # выходной каталог HTML до того, как изменения вступят в силу.
# # Значение по умолчанию: YES.
# # Этот тег требует, чтобы GENERATE_HTML тега был установлен в YES.
#
# FORMULA_TRANSPARENT = YES
#
# # Включите опцию USE_MATHJAX для рендеринга формул LaTeX с помощью MathJax (см.
# # http://www.mathjax.org), который использует клиентский Javascript для рендеринга
# # вместо использования предварительно отрисованных растровых изображений. Используйте это, если у вас нет LaTeX
# # или если вы хотите, чтобы формулы выглядели красивее в HTML-выводе. Когда
# # enabled, вам также может потребоваться установить MathJax отдельно и настроить путь
# # к нему с помощью опции MATHJAX_RELPATH.
# # Значение по умолчанию: NO.
# # Этот тег требует, чтобы GENERATE_HTML тега был установлен в YES.
#
# USE_MATHJAX = NO
#
# # Когда MathJax включен, вы можете установить формат вывода по умолчанию, который будет использоваться для
# # вывод MathJax. Посетите сайт MathJax (см.:
# # http://docs.mathjax.org/en/latest/output.html) для получения более подробной информации.
# # Возможные значения: HTML-CSS (который медленнее, но имеет лучшие
# # совместимость), NativeMML (т.е. MathML) и SVG.
# # Значение по умолчанию: HTML-CSS.
# # Этот тег требует, чтобы USE_MATHJAX тега был установлен в YES.
#
# MATHJAX_FORMAT         = HTML-CSS
#
# # Когда MathJax включен, вам нужно указать местоположение относительно HTML
# # выведите каталог с помощью опции MATHJAX_RELPATH. Каталог назначения
# # должен содержать скрипт MathJax.js. Например, если каталог mathjax
# # находится на том же уровне, что и выходной каталог HTML, то
# # MATHJAX_RELPATH должно быть .. /mathjax. Значение по умолчанию указывает на MathJax
# # Сеть доставки контента, чтобы вы могли быстро увидеть результат без установки
# # MathJax. Тем не менее, настоятельно рекомендуется установить локальную копию
# # MathJax с http://www.mathjax.org до развертывания.
# # Значение по умолчанию: http://cdn.mathjax.org/mathjax/latest.
# # Этот тег требует, чтобы USE_MATHJAX тега был установлен в YES.
#
# MATHJAX_RELPATH        = http://cdn.mathjax.org/mathjax/latest
#
# # Тег MATHJAX_EXTENSIONS может быть использован для указания одного или нескольких MathJax
# # имена расширений, которые должны быть включены во время рендеринга MathJax. Например
# # MATHJAX_EXTENSIONS = TeX/AMSmath TeX/AMSсимволы
# # Этот тег требует, чтобы USE_MATHJAX тега был установлен в YES.
#
# MATHJAX_EXTENSIONS     =
#
# # Тег MATHJAX_CODEFILE может быть использован для указания файла с кусками javascript
# # кода, который будет использоваться при запуске кода MathJax. Перейти на сайт MathJax
# # (см.: http://docs.mathjax.org/en/latest/output.html) для получения более подробной информации. Для
# # пример см. в документации.
# # Этот тег требует, чтобы USE_MATHJAX тега был установлен в YES.
#
# MATHJAX_CODEFILE       =
#
# # Когда тег SEARCHENGINE включен, doxygen сгенерирует окно поиска для
# # HTML-вывод. Базовая поисковая система использует javascript и DHTML и
# # должен работать в любом современном браузере. Обратите внимание, что при использовании HTML help
# # (GENERATE_HTMLHELP), справка Qt (GENERATE_QHP) или docsets (GENERATE_DOCSET)
# # Функция поиска уже есть, поэтому эту функцию, как правило, следует отключать.
# # Для больших проектов поисковая система на основе javascript может быть медленной, тогда
# # Включение SERVER_BASED_SEARCH может стать лучшим решением. Можно
# # поиск с помощью клавиатуры; Чтобы перейти к окну поиска, используйте <клавишу доступа> + S
# # (что такое <клавиша доступа> зависит от ОС и браузера, но обычно
# # <CTRL>, <ALT>/<option> или и то, и другое). В поле поиска используйте <курсор вниз
# #> для перехода в окно результатов поиска, по результатам можно перемещаться
# # с помощью клавиш <курсора>. Нажмите <Enter> для выбора элемента или <escape> для отмены
# # поиск. Параметры фильтра можно выбрать, когда курсор находится внутри
# # поисковой строки, нажав <Shift>+<курсор вниз>. Также здесь используются клавиши <курсора>
# # для выбора фильтра и <Enter> или <escape> для активации или отмены фильтра
# # опция.
# # Значение по умолчанию: YES.
# # Этот тег требует, чтобы GENERATE_HTML тега был установлен в YES.
#
# ПОИСКОВАЯ СИСТЕМА = YES
#
#
# # Когда тег SERVER_BASED_SEARCH включен, поисковая система будет
# # реализован с помощью веб-сервера вместо веб-клиента с использованием Javascript. Там
# # - это две разновидности поиска на основе веб-сервера в зависимости от EXTERNAL_SEARCH
# # настройка. При отключении doxygen сгенерирует PHP-скрипт для поиска и
# # индексный файл, используемый скриптом. Когда EXTERNAL_SEARCH включена, индексация
# # и поиск должен быть обеспечен внешними инструментами. Смотрите раздел
# # "Внешнее индексирование и поиск" для получения подробной информации.
# # Значение по умолчанию: NO.
# # Этот тег требует, чтобы тег SEARCHENGINE был установлен в YES.
#
# SERVER_BASED_SEARCH = NO
#
# # Когда тег EXTERNAL_SEARCH включен, doxygen больше не будет генерировать PHP
# # скрипт для поиска. Вместо этого результаты поиска записываются в XML-файл
# #, который должен быть обработан внешним индексатором. Doxygen вызовет
# # внешняя поисковая система, на которую указывает SEARCHENGINE_URL опция для получения
# # результаты поиска.
# #
# # Doxygen поставляется с примером индексатора ( doxyindexer) и поисковой системы
# # (doxysearch.cgi), которые основаны на библиотеке поисковых систем с открытым исходным кодом
# # Xapian (см.: http://xapian.org/).
# #
# # Подробнее см. раздел "Внешнее индексирование и поиск".
# # Значение по умолчанию: NO.
# # Этот тег требует, чтобы тег SEARCHENGINE был установлен в YES.
#
# EXTERNAL_SEARCH = NO
#
# # SEARCHENGINE_URL должен указывать на поисковую систему, размещенную на веб-сервере
# #, который будет возвращать результаты поиска, когда EXTERNAL_SEARCH включена.
# #
# # Doxygen поставляется с примером индексатора ( doxyindexer) и поисковой системы
# # (doxysearch.cgi), которые основаны на библиотеке поисковых систем с открытым исходным кодом
# # Xapian (см.: http://xapian.org/). Смотрите раздел «Внешнее индексирование и
# # Поиск» для получения подробной информации.
# # Этот тег требует, чтобы тег SEARCHENGINE был установлен в YES.
#
# SEARCHENGINE_URL       =
#
# # Когда и SERVER_BASED_SEARCH, и EXTERNAL_SEARCH включены, неиндексированные
# # Данные поиска записываются в файл для индексации внешним инструментом. С помощью
# # SEARCHDATA_FILE тег можно указать имя этого файла.
# # Файл по умолчанию: searchdata.xml.
# # Этот тег требует, чтобы тег SEARCHENGINE был установлен в YES.
#
# SEARCHDATA_FILE        = searchdata.xml
#
# # Когда и SERVER_BASED_SEARCH, и EXTERNAL_SEARCH включены,
# # EXTERNAL_SEARCH_ID тег может быть использован в качестве идентификатора проекта. Это
# # полезно в сочетании с EXTRA_SEARCH_MAPPINGS для поиска по нескольким
# # projects и перенаправить результаты обратно в нужный проект.
# # Этот тег требует, чтобы тег SEARCHENGINE был установлен в YES.
#
# EXTERNAL_SEARCH_ID     =
#
# # Тег EXTRA_SEARCH_MAPPINGS может быть использован для включения поиска по doxygen
# # проекты, отличные от того, который определен в этом конфигурационном файле, но которые
# # все добавлены в один и тот же внешний поисковый индекс. Каждый проект должен иметь
# # уникальный идентификатор, установленный через EXTERNAL_SEARCH_ID. Затем сопоставление поиска сопоставляет идентификатор
# # в относительное место, где можно найти документацию. Формат:
# # EXTRA_SEARCH_MAPPINGS = tagname1=loc1 tagname2=loc2 ...
# # Этот тег требует, чтобы тег SEARCHENGINE был установлен в YES.
#
# EXTRA_SEARCH_MAPPINGS  =
#
# #---------------------------------------------------------------------------
# # Параметры конфигурации, связанные с выводом LaTeX
# #---------------------------------------------------------------------------
#
# # Если тег GENERATE_LATEX установлен в YES, doxygen сгенерирует вывод LaTeX.
# # Значение по умолчанию: YES.
#
# GENERATE_LATEX = NO
#
# # Тег LATEX_OUTPUT используется для указания того, куда будут помещены документы LaTeX. Если
# # введен относительный путь, значение OUTPUT_DIRECTORY будет поставлено перед
# # это.
# # Каталог по умолчанию: latex.
# # Этот тег требует, чтобы GENERATE_LATEX тега был установлен в YES.
#
# LATEX_OUTPUT = latex
#
# # Тег LATEX_CMD_NAME может быть использован для указания имени команды LaTeX, которое должно быть
# # вызывается.
# #
# # Обратите внимание, что при включении USE_PDFLATEX эта опция используется только для генерации
# # растровые изображения для формул в выводе HTML, но не в файле Makefile, который
# # записывается в выходной каталог.
# # Файл по умолчанию: latex.
# # Этот тег требует, чтобы GENERATE_LATEX тега был установлен в YES.
#
# LATEX_CMD_NAME = latex
#
# # Тег MAKEINDEX_CMD_NAME можно использовать для указания имени генерируемой команды
# # индекс для LaTeX.
# # Файл по умолчанию: makeindex.
# # Этот тег требует, чтобы GENERATE_LATEX тега был установлен в YES.
#
# MAKEINDEX_CMD_NAME     = makeindex
#
# # Если тег COMPACT_LATEX установлен в YES, doxygen генерирует более компактный LaTeX
# # документы. Это может быть полезно для небольших проектов и может помочь сэкономить некоторые
# # деревья в целом.
# # Значение по умолчанию: NO.
# # Этот тег требует, чтобы GENERATE_LATEX тега был установлен в YES.
#
# COMPACT_LATEX = NO
#
# # Тег PAPER_TYPE может быть использован для установки типа бумаги, который используется
# # принтер.
# # Возможные значения: a4 (210 x 297 мм), letter (8,5 x 11 дюймов), legal (8,5 x )
# # 14 дюймов) и Executive (7,25 x 10,5 дюймов).
# # Значение по умолчанию: a4.
# # Этот тег требует, чтобы GENERATE_LATEX тега был установлен в YES.
#
# PAPER_TYPE             = a4
#
# # The EXTRA_PACKAGES tag can be used to specify one or more LaTeX package names
# # that should be included in the LaTeX output. To get the times font for
# # instance you can specify
# # EXTRA_PACKAGES=times
# # If left blank no extra packages will be included.
# # This tag requires that the tag GENERATE_LATEX is set to YES.
#
# EXTRA_PACKAGES         =
#
# # The LATEX_HEADER tag can be used to specify a personal LaTeX header for the
# # generated LaTeX document. The header should contain everything until the first
# # chapter. If it is left blank doxygen will generate a standard header. See
# # section "Doxygen usage" for information on how to let doxygen write the
# # default header to a separate file.
# #
# # Note: Only use a user-defined header if you know what you are doing! The
# # following commands have a special meaning inside the header: $title,
# # $datetime, $date, $doxygenversion, $projectname, $projectnumber. Doxygen will
# # replace them by respectively the title of the page, the current date and time,
# # only the current date, the version number of doxygen, the project name (see
# # PROJECT_NAME), or the project number (see PROJECT_NUMBER).
# # This tag requires that the tag GENERATE_LATEX is set to YES.
#
# LATEX_HEADER           =
#
# # The LATEX_FOOTER tag can be used to specify a personal LaTeX footer for the
# # generated LaTeX document. The footer should contain everything after the last
# # chapter. If it is left blank doxygen will generate a standard footer.
# #
# # Note: Only use a user-defined footer if you know what you are doing!
# # This tag requires that the tag GENERATE_LATEX is set to YES.
#
# LATEX_FOOTER           =
#
# # The LATEX_EXTRA_FILES tag can be used to specify one or more extra images or
# # other source files which should be copied to the LATEX_OUTPUT output
# # directory. Note that the files will be copied as-is; there are no commands or
# # markers available.
# # This tag requires that the tag GENERATE_LATEX is set to YES.
#
# LATEX_EXTRA_FILES      =
#
# # If the PDF_HYPERLINKS tag is set to YES, the LaTeX that is generated is
# # prepared for conversion to PDF (using ps2pdf or pdflatex). The PDF file will
# # contain links (just like the HTML output) instead of page references. This
# # makes the output suitable for online browsing using a PDF viewer.
# # The default value is: YES.
# # This tag requires that the tag GENERATE_LATEX is set to YES.
#
# PDF_HYPERLINKS         = YES
#
# # If the LATEX_PDFLATEX tag is set to YES, doxygen will use pdflatex to generate
# # the PDF file directly from the LaTeX files. Set this option to YES to get a
# # higher quality PDF documentation.
# # The default value is: YES.
# # This tag requires that the tag GENERATE_LATEX is set to YES.
#
# USE_PDFLATEX           = YES
#
# # If the LATEX_BATCHMODE tag is set to YES, doxygen will add the \batchmode
# # command to the generated LaTeX files. This will instruct LaTeX to keep running
# # if errors occur, instead of asking the user for help. This option is also used
# # when generating formulas in HTML.
# # The default value is: NO.
# # This tag requires that the tag GENERATE_LATEX is set to YES.
#
# LATEX_BATCHMODE        = NO
#
# # If the LATEX_HIDE_INDICES tag is set to YES then doxygen will not include the
# # index chapters (such as File Index, Compound Index, etc.) in the output.
# # The default value is: NO.
# # This tag requires that the tag GENERATE_LATEX is set to YES.
#
# LATEX_HIDE_INDICES     = NO
#
# # If the LATEX_SOURCE_CODE tag is set to YES then doxygen will include source
# # code with syntax highlighting in the LaTeX output.
# #
# # Note that which sources are shown also depends on other settings such as
# # SOURCE_BROWSER.
# # The default value is: NO.
# # This tag requires that the tag GENERATE_LATEX is set to YES.
#
# LATEX_SOURCE_CODE      = NO
#
# # The LATEX_BIB_STYLE tag can be used to specify the style to use for the
# # bibliography, e.g. plainnat, or ieeetr. See
# # http://en.wikipedia.org/wiki/BibTeX and \cite for more info.
# # The default value is: plain.
# # This tag requires that the tag GENERATE_LATEX is set to YES.
#
# LATEX_BIB_STYLE        = plain
#
# #---------------------------------------------------------------------------
# # Configuration options related to the RTF output
# #---------------------------------------------------------------------------
#
# # If the GENERATE_RTF tag is set to YES doxygen will generate RTF output. The
# # RTF output is optimized for Word 97 and may not look too pretty with other RTF
# # readers/editors.
# # The default value is: NO.
#
# GENERATE_RTF           = NO
#
# # The RTF_OUTPUT tag is used to specify where the RTF docs will be put. If a
# # relative path is entered the value of OUTPUT_DIRECTORY will be put in front of
# # it.
# # The default directory is: rtf.
# # This tag requires that the tag GENERATE_RTF is set to YES.
#
# RTF_OUTPUT             = rtf
#
# # If the COMPACT_RTF tag is set to YES doxygen generates more compact RTF
# # documents. This may be useful for small projects and may help to save some
# # trees in general.
# # The default value is: NO.
# # This tag requires that the tag GENERATE_RTF is set to YES.
#
# COMPACT_RTF            = NO
#
# # If the RTF_HYPERLINKS tag is set to YES, the RTF that is generated will
# # contain hyperlink fields. The RTF file will contain links (just like the HTML
# # output) instead of page references. This makes the output suitable for online
# # browsing using Word or some other Word compatible readers that support those
# # fields.
# #
# # Note: WordPad (write) and others do not support links.
# # The default value is: NO.
# # Этот тег требует, чтобы GENERATE_RTF тега был установлен в YES.
#
# RTF_HYPERLINKS = NO
#
# # Загрузка определений таблиц стилей из файла. Синтаксис похож на конфигурацию doxygen
# #, т.е. серия присваиваний. Вам остается только обеспечить замену,
# # отсутствующим определениям присваивается значение по умолчанию.
# #
# # Смотрите также раздел "Использование Doxygen" для получения информации о том, как сгенерировать
# # Таблица стилей по умолчанию, которую обычно использует doxygen.
# # Этот тег требует, чтобы GENERATE_RTF тега был установлен в YES.
#
# RTF_STYLESHEET_FILE    =
#
# # Установить необязательные переменные, используемые при генерации RTF-документа. Синтаксис следующий
# # Аналогично конфигурационному файлу dOxygen. Файл расширений шаблона может быть сгенерирован
# # с помощью doxygen -e rtf extensionFile.
# # Этот тег требует, чтобы GENERATE_RTF тега был установлен в YES.
#
# RTF_EXTENSIONS_FILE    =
#
# #---------------------------------------------------------------------------
# # Конфигурационные опции, связанные с выводом man-страницы
# #---------------------------------------------------------------------------
#
# # Если тег GENERATE_MAN установлен в YES, doxygen будет генерировать man-страницы для
# # классы и файлы.
# # Значение по умолчанию: NO.
#
# GENERATE_MAN = NO
#
# # Тег MAN_OUTPUT используется для указания того, где будут размещены man-страницы. Если
# # введен относительный путь, значение OUTPUT_DIRECTORY будет поставлено перед
# # это. Каталог man3 будет создан внутри каталога, указанного в
# # MAN_OUTPUT.
# # Каталог по умолчанию: man.
# # Этот тег требует, чтобы GENERATE_MAN тега был установлен в YES.
#
# MAN_OUTPUT = человек
#
# # Тег MAN_EXTENSION определяет расширение, которое добавляется к сгенерированному
# # man-страницы. В случае, если раздел руководства не начинается с числа, номер
# # 3 предваряется. Точка (.) в начале тега MAN_EXTENSION
# # необязательный.
# # Значение по умолчанию: .3.
# # Этот тег требует, чтобы GENERATE_MAN тега был установлен в YES.
#
# MAN_EXTENSION          = .3
#
# # Тег MAN_SUBDIR определяет имя каталога, созданного в
# # MAN_OUTPUT, в котором размещаются man-страницы. Если по умолчанию man
# # MAN_EXTENSION с начальным . удаленный.
# # Этот тег требует, чтобы GENERATE_MAN тега был установлен в YES.
#
# MAN_SUBDIR             =
#
# # Если тег MAN_LINKS установлен в YES и doxygen генерирует man output, то он
# # сгенерирует по одному дополнительному man-файлу для каждой сущности, задокументированной в реальном
# # справочная страница(ы). Эти дополнительные файлы содержат только реальную man-страницу, но без
# # их команда man не сможет найти нужную страницу.
# # Значение по умолчанию: NO.
# # Этот тег требует, чтобы GENERATE_MAN тега был установлен в YES.
#
# MAN_LINKS = NO
#
# #---------------------------------------------------------------------------
# # Параметры конфигурации, связанные с выводом XML
# #---------------------------------------------------------------------------
#
# # Если тег GENERATE_XML установлен в YES, doxygen сгенерирует XML-файл, который
# # фиксирует структуру кода, включая всю документацию.
# # Значение по умолчанию: NO.
#
# GENERATE_XML = NO
#
# # Тег XML_OUTPUT используется для указания того, где будут размещены XML-страницы. Если
# # введен относительный путь, значение OUTPUT_DIRECTORY будет поставлено перед
# # it.
# # The default directory is: xml.
# # This tag requires that the tag GENERATE_XML is set to YES.
#
# XML_OUTPUT             = xml
#
# # If the XML_PROGRAMLISTING tag is set to YES doxygen will dump the program
# # listings (including syntax highlighting and cross-referencing information) to
# # the XML output. Note that enabling this will significantly increase the size
# # of the XML output.
# # The default value is: YES.
# # This tag requires that the tag GENERATE_XML is set to YES.
#
# XML_PROGRAMLISTING     = YES
#
# #---------------------------------------------------------------------------
# # Configuration options related to the DOCBOOK output
# #---------------------------------------------------------------------------
#
# # If the GENERATE_DOCBOOK tag is set to YES doxygen will generate Docbook files
# # that can be used to generate PDF.
# # The default value is: NO.
#
# GENERATE_DOCBOOK       = NO
#
# # The DOCBOOK_OUTPUT tag is used to specify where the Docbook pages will be put.
# # If a relative path is entered the value of OUTPUT_DIRECTORY will be put in
# # front of it.
# # The default directory is: docbook.
# # This tag requires that the tag GENERATE_DOCBOOK is set to YES.
#
# DOCBOOK_OUTPUT         = docbook
#
# #---------------------------------------------------------------------------
# # Configuration options for the AutoGen Definitions output
# #---------------------------------------------------------------------------
#
# # If the GENERATE_AUTOGEN_DEF tag is set to YES doxygen will generate an AutoGen
# # Definitions (see http://autogen.sf.net) file that captures the structure of
# # the code including all documentation. Note that this feature is still
# # experimental and incomplete at the moment.
# # The default value is: NO.
#
# GENERATE_AUTOGEN_DEF   = NO
#
# #---------------------------------------------------------------------------
# # Configuration options related to the Perl module output
# #---------------------------------------------------------------------------
#
# # If the GENERATE_PERLMOD tag is set to YES doxygen will generate a Perl module
# # file that captures the structure of the code including all documentation.
# #
# # Note that this feature is still experimental and incomplete at the moment.
# # The default value is: NO.
#
# GENERATE_PERLMOD       = NO
#
# # If the PERLMOD_LATEX tag is set to YES doxygen will generate the necessary
# # Makefile rules, Perl scripts and LaTeX code to be able to generate PDF and DVI
# # output from the Perl module output.
# # The default value is: NO.
# # This tag requires that the tag GENERATE_PERLMOD is set to YES.
#
# PERLMOD_LATEX          = NO
#
# # If the PERLMOD_PRETTY tag is set to YES the Perl module output will be nicely
# # formatted so it can be parsed by a human reader. This is useful if you want to
# # understand what is going on. On the other hand, if this tag is set to NO the
# # size of the Perl module output will be much smaller and Perl will parse it
# # just the same.
# # The default value is: YES.
# # This tag requires that the tag GENERATE_PERLMOD is set to YES.
#
# PERLMOD_PRETTY         = YES
#
# # The names of the make variables in the generated doxyrules.make file are
# # prefixed with the string contained in PERLMOD_MAKEVAR_PREFIX. This is useful
# # so different doxyrules.make files included by the same Makefile don't
# # overwrite each other's variables.
# # This tag requires that the tag GENERATE_PERLMOD is set to YES.
#
# PERLMOD_MAKEVAR_PREFIX =
#
# #---------------------------------------------------------------------------
# # Configuration options related to the preprocessor
# #---------------------------------------------------------------------------
#
# # If the ENABLE_PREPROCESSING tag is set to YES doxygen will evaluate all
# # C-preprocessor directives found in the sources and include files.
# # The default value is: YES.
#
# ENABLE_PREPROCESSING   = YES
#
# # If the MACRO_EXPANSION tag is set to YES doxygen will expand all macro names
# # in the source code. If set to NO only conditional compilation will be
# # performed. Macro expansion can be done in a controlled way by setting
# # EXPAND_ONLY_PREDEF to YES.
# # The default value is: NO.
# # This tag requires that the tag ENABLE_PREPROCESSING is set to YES.
#
# MACRO_EXPANSION        = YES
#
# # If the EXPAND_ONLY_PREDEF and MACRO_EXPANSION tags are both set to YES then
# # расширение макроса ограничено макросами, указанными с помощью PREDEFINED и
# # EXPAND_AS_DEFINED теги.
# # Значение по умолчанию: NO.
# # Этот тег требует, чтобы ENABLE_PREPROCESSING тега был установлен в YES.
#
# EXPAND_ONLY_PREDEF = NO
#
# # Если тег SEARCH_INCLUDES установлен в значение YES, включаемые файлы в
# # INCLUDE_PATH будет выполняться поиск, если будет найден #include.
# # Значение по умолчанию: YES.
# # Этот тег требует, чтобы ENABLE_PREPROCESSING тега был установлен в YES.
#
# SEARCH_INCLUDES = YES
#
# # Тег INCLUDE_PATH может быть использован для указания одного или нескольких каталогов, которые
# # содержат включаемые файлы, которые не являются входными файлами, но должны быть обработаны методом
# # препроцессор.
# # Этот тег требует, чтобы SEARCH_INCLUDES тега был установлен в YES.
#
# INCLUDE_PATH           =
#
# # Вы можете использовать тег INCLUDE_FILE_PATTERNS для указания одного или нескольких подстановочных знаков
# # (например, *.h и *.hpp) для фильтрации заголовочных файлов в
# # каталоги. Если оставить пустым, шаблоны, указанные с помощью FILE_PATTERNS, будут следующими
# # используется.
# # Этот тег требует, чтобы ENABLE_PREPROCESSING тега был установлен в YES.
#
# INCLUDE_FILE_PATTERNS  =
#
# # Тег PREDEFINED может быть использован для указания одного или нескольких имен макросов, которые
# # определяется перед запуском препроцессора (аналогично опции -D, например,
# # gcc). Аргументом тега является список макросов вида: name или
# # name=definition (без пробелов). Если определение и "=" опущены, "=1"
# # предполагается. Чтобы предотвратить отмену определения макроса с помощью #undef или
# # при рекурсивном расширении используйте оператор := вместо оператора =.
# # Этот тег требует, чтобы ENABLE_PREPROCESSING тега был установлен в YES.
#
# ПРЕДОПРЕДЕЛЕННЫЙ =
#
# # Если теги MACRO_EXPANSION и EXPAND_ONLY_PREDEF установлены в YES, то это
# # можно использовать для указания списка имен макросов, которые должны быть развернуты. Тем
# # будет использовано определение макроса, найденное в исходных кодах. Используйте кнопку PREDEFINED
# #, если вы хотите использовать другое определение макроса, которое переопределяет
# # определение, найденное в исходном коде.
# # Этот тег требует, чтобы ENABLE_PREPROCESSING тега был установлен в YES.
#
# EXPAND_AS_DEFINED      =
#
# # Если тег SKIP_FUNCTION_MACROS установлен в YES, то препроцессор doxygen
# # удалить все ссылки на функции-подобные макросы, которые находятся только в строке, имеют
# # имя в верхнем регистре и не заканчивается точкой с запятой. Такие макросы функций
# # обычно используются для шаблонного кода и запутают парсер, если нет
# # удалено.
# # Значение по умолчанию: YES.
# # Этот тег требует, чтобы ENABLE_PREPROCESSING тега был установлен в YES.
#
# SKIP_FUNCTION_MACROS = YES
#
# #---------------------------------------------------------------------------
# # Параметры конфигурации, связанные с внешними ссылками
# #---------------------------------------------------------------------------
#
# # Тег TAGFILES может быть использован для указания одного или нескольких файлов тегов. Для каждого тега
# # file должно быть добавлено расположение внешней документации. Формат
# # Файл тегов без этого расположения выглядит следующим образом:
# # TAGFILES = файл1 файл2 ...
# # Добавление местоположения для файлов тегов осуществляется следующим образом:
# # TAGFILES = file1=loc1 "file2 = loc2" ...
# # где loc1 и loc2 могут быть относительными или абсолютными путями или URL-адресами. Смотрите
# # раздел "Ссылки на внешнюю документацию" для получения дополнительной информации об использовании
# # файлов тегов.
# # Замечание: Каждый файл тегов должен иметь уникальное имя (где имя НЕ включает
# # путь). Если файл тегов не находится в каталоге, в котором находится doxygen
# # run, здесь же необходимо указать путь к файлу тегов.
#
# TAGFILES               =
#
# # Когда имя файла указано после GENERATE_TAGFILE, doxygen создаст
# # файл тега, который основан на входных файлах, которые он считывает. Смотрите раздел "Ссылки на
# # Внешняя документация" для получения дополнительной информации об использовании файлов тегов.
#
# GENERATE_TAGFILE       =
#
# # Если тег ALLEXTERNALS установлен в значение YES, то все внешние классы будут перечислены в
# # индекс класса. Если установлено значение NO, будут перечислены только унаследованные внешние классы.
# # Значение по умолчанию: NO.
#
# ALLEXTERNALS = NO
#
# # Если тег EXTERNAL_GROUPS установлен в YES, то все внешние группы будут перечислены в
# # индекс модулей. Если установлено значение NO, будут только группы текущего проекта
# # перечислено.
# # Значение по умолчанию: YES.
#
# EXTERNAL_GROUPS = YES
#
# # Если тег EXTERNAL_PAGES установлен в YES, то все внешние страницы будут перечислены в
# # индекс связанных страниц. Если установлено значение NO, будут работать только страницы текущего проекта
# # быть в списке.
# # Значение по умолчанию: YES.
#
# EXTERNAL_PAGES = YES
#
# # В PERL_PATH должен быть абсолютный путь и имя perl-скрипта
# # интерпретатор (т.е. результат 'which perl').
# # Файл по умолчанию (с абсолютным путем): /usr/bin/perl.
#
# PERL_PATH              = /usr/bin/perl
#
# #---------------------------------------------------------------------------
# # Параметры конфигурации, относящиеся к точечному инструменту
# #---------------------------------------------------------------------------
#
# # Если тег CLASS_DIAGRAMS установлен в YES, doxygen сгенерирует диаграмму классов
# # (в HTML и LaTeX) для классов с базовыми или суперклассами. Установка тега в
# # NO отключает диаграммы. Обратите внимание, что эта опция также работает с HAVE_DOT
# # disabled, но рекомендуется установить и использовать dot, так как он дает больше
# # мощные графики.
# # Значение по умолчанию: YES.
#
# CLASS_DIAGRAMS = YES
#
# # Вы можете определить диаграммы последовательности сообщений в комментариях doxygen с помощью \msc
# # команда. После этого Doxygen запустит утилиту mscgen (см.:
# # http://www.mcternan.me.uk/mscgen/)), чтобы создать диаграмму и вставить ее в
# # документация. Тег MSCGEN_PATH позволяет указать каталог, в котором
# # Находится инструмент MSCGEN. Если оставить пустым, предполагается, что инструмент находится в папке
# # путь поиска по умолчанию.
#
# MSCGEN_PATH            =
#
# # Вы можете включить диаграммы, сделанные с помощью dia, в документацию doxygen. Doxygen будет
# # Затем запустите dia для создания диаграммы и вставьте ее в документацию. Тем
# # DIA_PATH тег позволяет указать каталог, в котором находится двоичный файл dia.
# # Если оставить пустым, предполагается, что dia находится в пути поиска по умолчанию.
#
# DIA_PATH               =
#
# # Если установлено значение YES, то графы наследования и совместной работы будут скрывать наследование
# # и отношения использования, если цель не документирована или не является классом.
# # Значение по умолчанию: YES.
#
# HIDE_UNDOC_RELATIONS = NO
#
# # Если вы установите тег HAVE_DOT в YES, то doxygen будет считать, что инструмент с точками
# # доступен из пути. Этот инструмент является частью Graphviz (см.:
# # http://www.graphviz.org/), набор инструментов для визуализации графов от AT&T и Lucent
# # Белл Лабс. Другие параметры в этом разделе не действуют, если этот параметр
# # установите значение NO
# # Значение по умолчанию: NO.
#
# HAVE_DOT = YES
#
# # В DOT_NUM_THREADS указывается количество вызовов точек doxygen
# # для параллельного запуска. Если установлено значение 0, doxygen будет основываться на количестве
# # процессоров, доступных в системе. Вы можете явно задать для него значение
# # больше 0, чтобы получить контроль над балансом между загрузкой процессора и обработкой
# # скорость.
# # Минимальное значение: 0, максимальное значение: 32, значение по умолчанию: 0.
# # Этот тег требует, чтобы тег HAVE_DOT был установлен в YES.
#
# DOT_NUM_THREADS        = 0
#
# # Если вы хотите, чтобы шрифт выглядел по-другому в точечных файлах, которые doxygen
# # генерирует вы можете указать имя шрифта с помощью DOT_FONTNAME. Вам нужно сделать
# # Конечно, точка может найти шрифт, что можно сделать, поместив его в
# # стандартного местоположения или установив переменную окружения DOTFONTPATH или с помощью
# # установка DOT_FONTPATH каталога, содержащего шрифт.
# # Значение по умолчанию: Helvetica.
# # Этот тег требует, чтобы тег HAVE_DOT был установлен в YES.
#
# DOT_FONTNAME = Гельветика
#
# # Тег DOT_FONTSIZE может быть использован для установки размера (в пунктах) шрифта
# # точечные графики.
# # Минимальное значение: 4, максимальное значение: 24, значение по умолчанию: 10.
# # Этот тег требует, чтобы тег HAVE_DOT был установлен в YES.
#
# DOT_FONTSIZE           = 10
#
# # По умолчанию doxygen укажет dot использовать шрифт по умолчанию, как указано в
# # DOT_FONTNAME. Если вы указываете другой шрифт с помощью DOT_FONTNAME вы можете установить
# # путь, по которому dot может найти его с помощью этого тега.
# # Этот тег требует, чтобы тег HAVE_DOT был установлен в YES.
#
# DOT_FONTPATH           =
#
# # Если тег CLASS_GRAPH установлен в YES, то doxygen сгенерирует график для
# # каждый документированный класс, показывающий отношения прямого и косвенного наследования.
# # Установка этого тега в YES приведет к тому, что CLASS_DIAGRAMS тег будет иметь значение NO.
# # Значение по умолчанию: YES.
# # Этот тег требует, чтобы тег HAVE_DOT был установлен в YES.
#
# CLASS_GRAPH = YES
#
# # Если тег COLLABORATION_GRAPH установлен в YES, то doxygen сгенерирует
# # граф для каждого документированного класса, показывающий прямую и косвенную реализацию
# # зависимости (наследование, вложение и переменные ссылок на классы) переменных
# # с другими документированными классами.
# # Значение по умолчанию: YES.
# # Этот тег требует, чтобы тег HAVE_DOT был установлен в YES.
#
# COLLABORATION_GRAPH = YES
#
# # Если тег GROUP_GRAPHS установлен в YES, то doxygen сгенерирует график для
# # groups, показывающие прямые зависимости групп.
# # Значение по умолчанию: YES.
# # Этот тег требует, чтобы тег HAVE_DOT был установлен в YES.
#
# GROUP_GRAPHS = YES
#
# # Если тег UML_LOOK установлен в YES, doxygen сгенерирует наследование и
# # диаграммы коллаборации в стиле, похожем на Унифицированное моделирование OMG
# # Язык.
# # Значение по умолчанию: NO.
# # Этот тег требует, чтобы тег HAVE_DOT был установлен в YES.
#
# UML_LOOK = NO
#
# # Если тег UML_LOOK включен, то поля и методы показываются внутри тега
# # узел класса. Если имеется много полей или методов и много узлов, граф может
# # становятся слишком большими, чтобы быть полезными. Порог UML_LIMIT_NUM_FIELDS ограничивает
# # количество элементов для каждого типа, чтобы сделать размер более управляемым. Установите значение 0
# # без ограничений. Обратите внимание, что порог может быть превышен на 50% раньше лимита
# # принудительно. Таким образом, когда вы установите порог в 10, может появиться до 15 полей,
# # но если это число превышает 15, то общее количество отображаемых полей ограничивается
# # 10.
# # Минимальное значение: 0, максимальное значение: 100, значение по умолчанию: 10.
# # Этот тег требует, чтобы тег HAVE_DOT был установлен в YES.
#
# UML_LIMIT_NUM_FIELDS   = 10
#
# # Если тег TEMPLATE_RELATIONS установлен в YES, то наследование и
# # графики совместной работы покажут отношения между шаблонами и их
# # экземпляры.
# # Значение по умолчанию: NO.
# # Этот тег требует, чтобы тег HAVE_DOT был установлен в YES.
#
# TEMPLATE_RELATIONS = NO
#
# # Если теги INCLUDE_GRAPH, ENABLE_PREPROCESSING и SEARCH_INCLUDES установлены в значение
# # YES, то doxygen сгенерирует график для каждого задокументированного файла, показывающий
# # прямое и косвенное включение зависимостей файла с другими документированными
# # файлов.
# # Значение по умолчанию: YES.
# # Этот тег требует, чтобы тег HAVE_DOT был установлен в YES.
#
# INCLUDE_GRAPH = YES
#
# # Если теги INCLUDED_BY_GRAPH, ENABLE_PREPROCESSING и SEARCH_INCLUDES равны
# # установите значение YES, то doxygen сгенерирует график для каждого задокументированного файла, показывающий
# # прямые и косвенные включают зависимости файла с другими документированными
# # файлов.
# # Значение по умолчанию: YES.
# # Этот тег требует, чтобы тег HAVE_DOT был установлен в YES.
#
# INCLUDED_BY_GRAPH = YES
#
# # Если тег CALL_GRAPH установлен в YES, то doxygen сгенерирует вызов
# # граф зависимостей для каждой глобальной функции или метода класса.
# #
# # Обратите внимание, что включение этой опции значительно увеличит время выполнения.
# # Поэтому в большинстве случаев будет лучше включить графики вызовов для выбранных
# # функционирует только с помощью команды \callgraph.
# # Значение по умолчанию: NO.
# # Этот тег требует, чтобы тег HAVE_DOT был установлен в YES.
#
# CALL_GRAPH = YES
#
# # Если тег CALLER_GRAPH установлен в YES, то doxygen сгенерирует вызывающего абонента
# # граф зависимостей для каждой глобальной функции или метода класса.
# #
# # Обратите внимание, что включение этой опции значительно увеличит время выполнения.
# # Поэтому в большинстве случаев будет лучше включить графики вызывающих абонентов для выбранных
# # функционирует только с помощью команды \callergraph.
# # Значение по умолчанию: NO.
# # Этот тег требует, чтобы тег HAVE_DOT был установлен в YES.
#
# CALLER_GRAPH = YES
#
# # Если тег GRAPHICAL_HIERARCHY установлен в YES, то doxygen будет графически
# # иерархия всех классов вместо текстовой.
# # Значение по умолчанию: YES.
# # Этот тег требует, чтобы тег HAVE_DOT был установлен в YES.
#
# GRAPHICAL_HIERARCHY = YES
#
# # Если тег DIRECTORY_GRAPH установлен в YES, то doxygen покажет
# # зависимости каталога от других каталогов в графическом виде. Тем
# # отношения зависимостей определяются #include отношениями между
# # в каталогах.
# # Значение по умолчанию: YES.
# # Этот тег требует, чтобы тег HAVE_DOT был установлен в YES.
#
# DIRECTORY_GRAPH = YES
#
# # Тег DOT_IMAGE_FORMAT можно использовать для установки формата изображений
# # генерируется точкой.
# # Замечание: Если вы выбираете svg, вам нужно установить HTML_FILE_EXTENSION в xhtml по порядку
# #, чтобы сделать SVG-файлы видимыми в IE 9+ (в других браузерах этого нет
# # требование).
# # Возможные значения: png, jpg, gif и svg.
# # Значение по умолчанию: png.
# # Этот тег требует, чтобы тег HAVE_DOT был установлен в YES.
#
# DOT_IMAGE_FORMAT       = png
#
# # Если DOT_IMAGE_FORMAT установлено в svg, то эта опция может быть установлена в YES, чтобы
# # включить генерацию интерактивных SVG-изображений, которые позволяют масштабировать и панорамировать.
# #
# # Обратите внимание, что для этого требуется современный браузер, отличный от Internet Explorer. Испытанный
# # и работают Firefox, Chrome, Safari и Opera.
# # Замечание: Для IE 9+ вам нужно установить HTML_FILE_EXTENSION в xhtml, чтобы сделать
# # видимые SVG-файлы. Более старые версии IE не поддерживают SVG.
# # Значение по умолчанию: NO.
# # Этот тег требует, чтобы тег HAVE_DOT был установлен в YES.
# # В случае, если включено построение графов при помощи Graphviz и в качестве формата
# # построения графов указан SVG, Doxygen будет создавать интерактивные SVG файлы,
# # которые можно увеличивать и перемещать
#
# INTERACTIVE_SVG = YES
#
# # Тег DOT_PATH может быть использован для указания пути, по которому может находиться точечный инструмент
# # найдено. Если оставить пустым, предполагается, что точечный инструмент может быть найден в контуре.
# # Этот тег требует, чтобы тег HAVE_DOT был установлен в YES.
#
# DOT_PATH               =
#
# # Тег DOTFILE_DIRS может быть использован для указания одного или нескольких каталогов, которые
# # содержат точечные файлы, которые включены в документацию (см. \dotfile
# #).
# # Этот тег требует, чтобы тег HAVE_DOT был установлен в YES.
#
# DOTFILE_DIRS           =
#
# # Тег MSCFILE_DIRS может быть использован для указания одного или нескольких каталогов, которые
# # содержат файлы msc, которые включены в документацию (см. файл \mscfile
# #).
#
# MSCFILE_DIRS           =
#
# # Тег DIAFILE_DIRS может быть использован для указания одного или нескольких каталогов, которые
# # содержат файлы dia, которые включены в документацию (см. файл \diafile
# #).
#
# DIAFILE_DIRS           =
#
# # Тег DOT_GRAPH_MAX_NODES можно использовать для установки максимального количества узлов
# #, который будет показан на графике. Если число узлов в графе станет равным
# # больше этого значения, doxygen будет усекать график, который визуализируется
# #, представляя узел в виде красного прямоугольника. Заметим, что doxygen, если количество прямых
# # потомки корневого узла в графе уже больше, чем
# # DOT_GRAPH_MAX_NODES то график вообще не будет показываться. Также обратите внимание, что
# # Размер графика может быть дополнительно ограничен MAX_DOT_GRAPH_DEPTH.
# # Минимальное значение: 0, максимальное значение: 10000, значение по умолчанию: 50.
# # Этот тег требует, чтобы тег HAVE_DOT был установлен в YES.
#
# DOT_GRAPH_MAX_NODES    = 50
#
# # Тег MAX_DOT_GRAPH_DEPTH можно использовать для установки максимальной глубины графиков
# # генерируется точкой. Значение глубины, равное 3, означает, что только узлы, достижимые из
# # root, следуя по пути не более чем через 3 ребра. Узлы, которые прокладывают
# # дальше от корневого узла будет опущено. Обратите внимание, что установка этого параметра в 1
# # или 2 может значительно сократить время вычислений, необходимое для больших баз кода. Тоже
# # обратите внимание, что размер графика может быть дополнительно ограничен
# # DOT_GRAPH_MAX_NODES. Использование глубины, равной 0, означает отсутствие ограничений по глубине.
# # Минимальное значение: 0, максимальное значение: 1000, значение по умолчанию: 0.
# # Этот тег требует, чтобы тег HAVE_DOT был установлен в YES.
#
# MAX_DOT_GRAPH_DEPTH    = 0
#
# # Установите тег DOT_TRANSPARENT в значение YES, чтобы генерировать изображения с прозрачным
# # предыстория. По умолчанию эта опция отключена, потому что точка в Windows не кажется
# # для поддержки этого из коробки.
# #
# # Внимание: В зависимости от используемой платформы, включение этой опции может привести к
# # плохо сглаженные метки на краях графа (т.е. их становится трудно
# # читать).
# # Значение по умолчанию: NO.
# # Этот тег требует, чтобы тег HAVE_DOT был установлен в YES.
#
# DOT_TRANSPARENT = NO
#
# # Установите тег DOT_MULTI_TARGETS в YES, чтобы разрешить точке генерировать несколько выходных данных
# # файлов за один запуск (т.е. несколько опций -o и -T в командной строке). Этот
# # ускоряет работу dot, но так как только новые версии dot (>1.8.10) поддерживают
# # this, эта функция отключена по умолчанию.
# # Значение по умолчанию: NO.
# # Этот тег требует, чтобы тег HAVE_DOT был установлен в YES.
#
# DOT_MULTI_TARGETS = NO
#
# # Если тег GENERATE_LEGEND установлен в YES, doxygen сгенерирует страницу легенды
# # объяснение значения различных прямоугольников и стрелок в сгенерированной точке
# # графики.
# # Значение по умолчанию: YES.
# # Этот тег требует, чтобы тег HAVE_DOT был установлен в YES.
#
# GENERATE_LEGEND = YES
#
# # Если тег DOT_CLEANUP установлен в YES, doxygen удалит промежуточную точку
# # файлы, которые используются для генерации различных графиков.
# # Значение по умолчанию: YES.
# # Этот тег требует, чтобы тег HAVE_DOT был установлен в YES.
#
# DOT_CLEANUP = YES
# </pre>

# %% [markdown]
#  <style>
#     td {
#       text-align: left;
#     }
#   </style>
#
# <table>
#   <tbody>
#     <tr>
#       <td><b>Команда</b></td>
#       <td><b>Значение</b></td>
#     </tr>
#     <tr>
#       <td>\authors</td>
#       <td>Указывает автора или авторов</td>
#     </tr>
#     <tr>
#       <td>\version</td>
#       <td>Используется для указания версии</td>
#     </tr>
#     <tr>
#       <td>\date</td>
#       <td>Предназначена для указания даты разработки</td>
#     </tr>
#     <tr>
#       <td>\bug</td>
#       <td>Перечисление известных ошибок</td>
#     </tr>
#     <tr>
#       <td>\warning</td>
#       <td>Предупреждение для использования</td>
#     </tr>
#     <tr>
#       <td>\copyright</td>
#       <td>Используемая лицензия</td>
#     </tr>
#     <tr>
#       <td>\example</td>
#       <td>Команда, добавляемая в комментарий для указания ссылки на исходник с примером (добавляется после команды)</td>
#     </tr>
#     <tr>
#       <td>\todo</td>
#       <td>Команда, используется для описания тех изменений, которые необходимо будет сделать (TODO).</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Далее будут использоваться следующие обозначения при описании аргументов команды, когда будет приводиться её общий формат:

# %% [markdown]
#  <style>
#     table {
#       text-align: left;
#     }
#
#     td {
#       border: 1px solid black; /* Пример добавления границ для наглядности */
#       padding: 8px; /* Пример добавления отступов для наглядности */
#     }
#   </style>
# </head>
# <body>
#
# <table>
#   <tbody>
#     <tr>
#       <td><b>Обозначение</b></td>
#       <td><b>Значение</b></td>
#     </tr>
#     <tr>
#       <td>&lt;. &gt;</td>
#       <td>Угловые скобки показывают, что аргумент представляет собой одно слово</td>
#     </tr>
#     <tr>
#       <td>(. )</td>
#       <td>Круглые скобки показывают, что аргументом является весь текст вплоть до конца строки, на которой размещена команда</td>
#     </tr>
#     <tr>
#       <td>{. } </td>
#       <td>Фигурные скобки показывают, что аргументом является весь текст вплоть до следующего параграфа. Параграфы разделяются пустой строкой или командой-разделителем</td>
#     </tr>
#   </tbody>
# </table>
